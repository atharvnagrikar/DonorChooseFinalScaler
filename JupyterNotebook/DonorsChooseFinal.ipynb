# %%
# Importing the  required libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Mounting the google drive on colab
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Data Analysis and Pre-processing

# %%
# reading .csv file
train_data_df= pd.read_csv("/content/drive/MyDrive/DSML/Business Case Study/Portfolio/1.DS_Portfolio/train_data.csv",index_col=0)
train_data_df.head(5)
# Out:
#              id                        teacher_id teacher_prefix school_state  \
# 160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.           IN
# 140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.           FL
# 21895   p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.           AZ
# 45      p246581  f3cb9bffbba169bef1a77b243e620b60           Mrs.           KY
# 172407  p104768  be1f7507a41f8479dc06f047086a39ec           Mrs.           TX
#
#        project_submitted_datetime project_grade_category  \
# 160221        2016-12-05 13:43:57          Grades PreK-2
# 140945        2016-10-25 09:22:10             Grades 6-8
# 21895         2016-08-31 12:03:56             Grades 6-8
# 45            2016-10-06 21:16:17          Grades PreK-2
# 172407        2016-07-11 01:10:09          Grades PreK-2
#
#                  project_subject_categories     project_subject_subcategories  \
# 160221                  Literacy & Language                     ESL, Literacy
# 140945    History & Civics, Health & Sports  Civics & Government, Team Sports
# 21895                       Health & Sports    Health & Wellness, Team Sports
# 45      Literacy & Language, Math & Science             Literacy, Mathematics
# 172407                       Math & Science                       Mathematics
#
#                                             project_title  \
# 160221   Educational Support for English Learners at Home
# 140945              Wanted: Projector for Hungry Learners
# 21895   Soccer Equipment for AWESOME Middle School Stu...
# 45                                 Techie Kindergarteners
# 172407                             Interactive Math Tools
#
#                                           project_essay_1  \
# 160221  My students are English learners that are work...
# 140945  Our students arrive to our school eager to lea...
# 21895   \r\n\"True champions aren't always the ones th...
# 45      I work at a unique school filled with both ESL...
# 172407  Our second grade classroom next year will be m...
#
#                                           project_essay_2 project_essay_3  \
# 160221  \"The limits of your language are the limits o...             NaN
# 140945  The projector we need for our school is very c...             NaN
# 21895   The students on the campus come to school know...             NaN
# 45      My students live in high poverty conditions wi...             NaN
# 172407  For many students, math is a subject that does...             NaN
#
#        project_essay_4                           project_resource_summary  \
# 160221             NaN  My students need opportunities to practice beg...
# 140945             NaN  My students need a projector to help with view...
# 21895              NaN  My students need shine guards, athletic socks,...
# 45                 NaN  My students need to engage in Reading and Math...
# 172407             NaN  My students need hands on practice in mathemat...
#
#         teacher_number_of_previously_posted_projects  project_is_approved
# 160221                                             0                    0
# 140945                                             7                    1
# 21895                                              1                    0
# 45                                                 4                    1
# 172407                                             1                    1

# %%
# shape
train_data_df.shape
# Out:
# (109248, 16)

# %%
# description
train_data_df.describe()
# Out:
#        teacher_number_of_previously_posted_projects  project_is_approved
# count                                 109248.000000        109248.000000
# mean                                      11.153165             0.848583
# std                                       27.777154             0.358456
# min                                        0.000000             0.000000
# 25%                                        0.000000             1.000000
# 50%                                        2.000000             1.000000
# 75%                                        9.000000             1.000000
# max                                      451.000000             1.000000

# %%
# info
train_data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109248 entries, 160221 to 128381
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   id                                            109248 non-null  object
#  1   teacher_id                                    109248 non-null  object
#  2   teacher_prefix                                109245 non-null  object
#  3   school_state                                  109248 non-null  object
#  4   project_submitted_datetime                    109248 non-null  object
#  5   project_grade_category                        109248 non-null  object
#  6   project_subject_categories                    109248 non-null  object
#  7   project_subject_subcategories                 109248 non-null  object
#  8   project_title                                 109248 non-null  object
#  9   project_essay_1                               109248 non-null  object
#  10  project_essay_2                               109248 non-null  object
#  11  project_essay_3                               3758 non-null    object
#  12  project_essay_4                               3758 non-null    object
#  13  project_resource_summary                      109248 non-null  object
#  14  teacher_number_of_previously_posted_projects  109248 non-null  int64
#  15  project_is_approved                           109248 non-null  int64
# dtypes: int64(2), object(14)
# memory usage: 14.2+ MB

# %%
# checking Null values
train_data_df.isnull().sum()
# Out:
# id                                                   0
# teacher_id                                           0
# teacher_prefix                                       3
# school_state                                         0
# project_submitted_datetime                           0
# project_grade_category                               0
# project_subject_categories                           0
# project_subject_subcategories                        0
# project_title                                        0
# project_essay_1                                      0
# project_essay_2                                      0
# project_essay_3                                 105490
# project_essay_4                                 105490
# project_resource_summary                             0
# teacher_number_of_previously_posted_projects         0
# project_is_approved                                  0
# dtype: int64

# %%
# columns names
train_data_df.columns
# Out:
# Index(['id', 'teacher_id', 'teacher_prefix', 'school_state',
#        'project_submitted_datetime', 'project_grade_category',
#        'project_subject_categories', 'project_subject_subcategories',
#        'project_title', 'project_essay_1', 'project_essay_2',
#        'project_essay_3', 'project_essay_4', 'project_resource_summary',
#        'teacher_number_of_previously_posted_projects', 'project_is_approved'],
#       dtype='object')

# %%
# analysis of resource.csv
# reading .csv file
resource_df= pd.read_csv("/content/drive/MyDrive/DSML/Business Case Study/Portfolio/1.DS_Portfolio/resources.csv")
resource_df.head(4)
# Out:
#         id                                        description  quantity  \
# 0  p233245  LC652 - Lakeshore Double-Space Mobile Drying Rack         1
# 1  p069063        Bouncy Bands for Desks (Blue support pipes)         3
# 2  p069063  Cory Stories: A Kid's Book About Living With Adhd         1
# 3  p069063  Dixon Ticonderoga Wood-Cased #2 HB Pencils, Bo...         2
#
#     price
# 0  149.00
# 1   14.95
# 2    8.45
# 3   13.59

# %%
# shape
resource_df.shape
# Out:
# (1541272, 4)

# %%
# describe
resource_df.describe()
# Out:
#            quantity         price
# count  1.541272e+06  1.541272e+06
# mean   2.860509e+00  5.028398e+01
# std    7.570345e+00  1.447326e+02
# min    1.000000e+00  0.000000e+00
# 25%    1.000000e+00  7.900000e+00
# 50%    1.000000e+00  1.499000e+01
# 75%    2.000000e+00  3.980000e+01
# max    8.000000e+02  9.999000e+03

# %%
# info
resource_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1541272 entries, 0 to 1541271
# Data columns (total 4 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1541272 non-null  object
#  1   description  1540980 non-null  object
#  2   quantity     1541272 non-null  int64
#  3   price        1541272 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 47.0+ MB

# %%
# checking null values
resource_df.isnull().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1541272 entries, 0 to 1541271
# Data columns (total 4 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   id           1541272 non-null  bool
#  1   description  1541272 non-null  bool
#  2   quantity     1541272 non-null  bool
#  3   price        1541272 non-null  bool
# dtypes: bool(4)
# memory usage: 5.9 MB

# %% [markdown]
# Handeling Null values

# %%
# checking null values
train_data_df.isnull().sum()
# Out:
# id                                                   0
# teacher_id                                           0
# teacher_prefix                                       3
# school_state                                         0
# project_submitted_datetime                           0
# project_grade_category                               0
# project_subject_categories                           0
# project_subject_subcategories                        0
# project_title                                        0
# project_essay_1                                      0
# project_essay_2                                      0
# project_essay_3                                 105490
# project_essay_4                                 105490
# project_resource_summary                             0
# teacher_number_of_previously_posted_projects         0
# project_is_approved                                  0
# dtype: int64

# %%
# checking teacher prefix null values
train_df_null=train_data_df[train_data_df["teacher_prefix"].isnull()]
train_df_null
# Out:
#              id                        teacher_id teacher_prefix school_state  \
# 17809   p180947  834f75f1b5e24bd10abe9c3dbf7ba12f            NaN           CA
# 22174   p002730  339bd5a9e445d68a74d65b99cd325397            NaN           SC
# 158692  p197901  e4be6aaaa887d4202df2b647fbfc82bb            NaN           PA
#
#        project_submitted_datetime project_grade_category  \
# 17809         2016-11-04 00:15:45             Grades 3-5
# 22174         2016-05-09 09:38:40            Grades 9-12
# 158692        2016-06-03 10:15:05             Grades 3-5
#
#                  project_subject_categories  \
# 17809   Literacy & Language, Math & Science
# 22174                   Literacy & Language
# 158692  Literacy & Language, Math & Science
#
#             project_subject_subcategories  \
# 17809   Literature & Writing, Mathematics
# 22174                Literature & Writing
# 158692              Literacy, Mathematics
#
#                                            project_title  \
# 17809   1:7 Increasing Tech to Decrease Achievement Gaps
# 22174                            iPads for STEM Stations
# 158692                                   Document Camera
#
#                                           project_essay_1  \
# 17809   The children at Anna Yates Elementary school a...
# 22174   Within the next 20 years, every job will invol...
# 158692  Students at Robertsdale Elementary live in a l...
#
#                                           project_essay_2  \
# 17809   My goal is to bring in 1 laptop for every 7 st...
# 22174   The students in our school come from a wide va...
# 158692  This SMART Document Camera will improve my stu...
#
#                                           project_essay_3  \
# 17809                                                 NaN
# 22174   Students will use the iPad station for individ...
# 158692                                                NaN
#
#                                           project_essay_4  \
# 17809                                                 NaN
# 22174   Your generosity will allow my students to work...
# 158692                                                NaN
#
#                                  project_resource_summary  \
# 17809   My students need a classroom laptop that is ju...
# 22174         My students need 5 iPads for STEM stations.
# 158692  My students need a Smart Document Camera to en...
#
#         teacher_number_of_previously_posted_projects  project_is_approved
# 17809                                              1                    1
# 22174                                              0                    1
# 158692                                             0                    1

# %%
# checking duplicate rws based on teacher id p180947
train_data_df[train_data_df["id"]=="p180947"]
# Out:
#             id                        teacher_id teacher_prefix school_state  \
# 17809  p180947  834f75f1b5e24bd10abe9c3dbf7ba12f            NaN           CA
#
#       project_submitted_datetime project_grade_category  \
# 17809        2016-11-04 00:15:45             Grades 3-5
#
#                 project_subject_categories      project_subject_subcategories  \
# 17809  Literacy & Language, Math & Science  Literature & Writing, Mathematics
#
#                                           project_title  \
# 17809  1:7 Increasing Tech to Decrease Achievement Gaps
#
#                                          project_essay_1  \
# 17809  The children at Anna Yates Elementary school a...
#
#                                          project_essay_2 project_essay_3  \
# 17809  My goal is to bring in 1 laptop for every 7 st...             NaN
#
#       project_essay_4                           project_resource_summary  \
# 17809             NaN  My students need a classroom laptop that is ju...
#
#        teacher_number_of_previously_posted_projects  project_is_approved
# 17809                                             1                    1

# %%
# checking duplicate rws based on teacher id p002730
train_data_df[train_data_df["id"]=="p002730"]
# Out:
#             id                        teacher_id teacher_prefix school_state  \
# 22174  p002730  339bd5a9e445d68a74d65b99cd325397            NaN           SC
#
#       project_submitted_datetime project_grade_category  \
# 22174        2016-05-09 09:38:40            Grades 9-12
#
#       project_subject_categories project_subject_subcategories  \
# 22174        Literacy & Language          Literature & Writing
#
#                  project_title  \
# 22174  iPads for STEM Stations
#
#                                          project_essay_1  \
# 22174  Within the next 20 years, every job will invol...
#
#                                          project_essay_2  \
# 22174  The students in our school come from a wide va...
#
#                                          project_essay_3  \
# 22174  Students will use the iPad station for individ...
#
#                                          project_essay_4  \
# 22174  Your generosity will allow my students to work...
#
#                           project_resource_summary  \
# 22174  My students need 5 iPads for STEM stations.
#
#        teacher_number_of_previously_posted_projects  project_is_approved
# 22174                                             0                    1

# %%
# checking duplicate rws based on teacher id p197901
train_data_df[train_data_df["id"]=="p197901"]
# Out:
#              id                        teacher_id teacher_prefix school_state  \
# 158692  p197901  e4be6aaaa887d4202df2b647fbfc82bb            NaN           PA
#
#        project_submitted_datetime project_grade_category  \
# 158692        2016-06-03 10:15:05             Grades 3-5
#
#                  project_subject_categories project_subject_subcategories  \
# 158692  Literacy & Language, Math & Science         Literacy, Mathematics
#
#           project_title                                    project_essay_1  \
# 158692  Document Camera  Students at Robertsdale Elementary live in a l...
#
#                                           project_essay_2 project_essay_3  \
# 158692  This SMART Document Camera will improve my stu...             NaN
#
#        project_essay_4                           project_resource_summary  \
# 158692             NaN  My students need a Smart Document Camera to en...
#
#         teacher_number_of_previously_posted_projects  project_is_approved
# 158692                                             0                    1

# %%
# Dropping Null value
train_data_df.dropna(subset=['teacher_prefix'], inplace=True)
train_data_df.shape
# Out:
# (109245, 16)

# %%
# checking null values
train_data_df.isnull().sum()
# Out:
# id                                                   0
# teacher_id                                           0
# teacher_prefix                                       0
# school_state                                         0
# project_submitted_datetime                           0
# project_grade_category                               0
# project_subject_categories                           0
# project_subject_subcategories                        0
# project_title                                        0
# project_essay_1                                      0
# project_essay_2                                      0
# project_essay_3                                 105488
# project_essay_4                                 105488
# project_resource_summary                             0
# teacher_number_of_previously_posted_projects         0
# project_is_approved                                  0
# dtype: int64

# %% [markdown]
# Data Preprocessing

# %%
train_data_df.head(2)
# Out:
#              id                        teacher_id teacher_prefix school_state  \
# 160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.           IN
# 140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.           FL
#
#        project_submitted_datetime project_grade_category  \
# 160221        2016-12-05 13:43:57          Grades PreK-2
# 140945        2016-10-25 09:22:10             Grades 6-8
#
#                project_subject_categories     project_subject_subcategories  \
# 160221                Literacy & Language                     ESL, Literacy
# 140945  History & Civics, Health & Sports  Civics & Government, Team Sports
#
#                                            project_title  \
# 160221  Educational Support for English Learners at Home
# 140945             Wanted: Projector for Hungry Learners
#
#                                           project_essay_1  \
# 160221  My students are English learners that are work...
# 140945  Our students arrive to our school eager to lea...
#
#                                           project_essay_2 project_essay_3  \
# 160221  \"The limits of your language are the limits o...             NaN
# 140945  The projector we need for our school is very c...             NaN
#
#        project_essay_4                           project_resource_summary  \
# 160221             NaN  My students need opportunities to practice beg...
# 140945             NaN  My students need a projector to help with view...
#
#         teacher_number_of_previously_posted_projects  project_is_approved
# 160221                                             0                    0
# 140945                                             7                    1

# %%
# Working on project subject category
projct_subject_category=train_data_df["project_subject_categories"]
projct_subject_category.head(20)
# Out:
# 160221                      Literacy & Language
# 140945        History & Civics, Health & Sports
# 21895                           Health & Sports
# 45          Literacy & Language, Math & Science
# 172407                           Math & Science
# 141660       Literacy & Language, Special Needs
# 21147        Literacy & Language, Special Needs
# 94142                            Math & Science
# 112489                          Health & Sports
# 158561                      Literacy & Language
# 43184                       Literacy & Language
# 127083    Literacy & Language, Applied Learning
# 19090                            Math & Science
# 15126                             Special Needs
# 62232                       Literacy & Language
# 67303                           Health & Sports
# 127215       Literacy & Language, Special Needs
# 157771      Math & Science, Literacy & Language
# 122186                         Applied Learning
# 146331                          Health & Sports
# Name: project_subject_categories, dtype: object

# %%
'''
Formatting of data in the following way
1) Literacy & Language to Literacy_Language
2) History & Civics, Health & Sports to History_Civics Health_Sports
'''
# Out:
# '\nFormatting of data in the following way\n1) Literacy & Language to Literacy_Language\n2) History & Civics, Health & Sports to History_Civics Health_Sports\n'

# %%
# Remove ampersands, split the strings by commas
train_data_df['project_subject_categories_updated'] = train_data_df['project_subject_categories'].str.replace("&", "").str.split(",")

# Remove leading/trailing spaces, convert to lowercase, replace spaces with underscores
train_data_df['project_subject_categories_updated'] = train_data_df['project_subject_categories_updated'].apply(lambda words: [word.strip().lower().replace(" ", "_") for word in words])

# Concatenate the categories into a single string
train_data_df['project_subject_categories_updated'] = train_data_df['project_subject_categories_updated'].apply(lambda words: " ".join(words))
# Replace double underscores with single underscores
train_data_df['project_subject_categories_updated'] = train_data_df['project_subject_categories_updated'].str.replace("__", "_")

train_data_df.head(40)
# Out:
#              id                        teacher_id teacher_prefix school_state  \
# 160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.           IN
# 140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.           FL
# 21895   p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.           AZ
# 45      p246581  f3cb9bffbba169bef1a77b243e620b60           Mrs.           KY
# 172407  p104768  be1f7507a41f8479dc06f047086a39ec           Mrs.           TX
# 141660  p154343  a50a390e8327a95b77b9e495b58b9a6e           Mrs.           FL
# 21147   p099819  9b40170bfa65e399981717ee8731efc3           Mrs.           CT
# 94142   p092424  5bfd3d12fae3d2fe88684bbac570c9d2            Ms.           GA
# 112489  p045029  487448f5226005d08d36bdd75f095b31           Mrs.           SC
# 158561  p001713  140eeac1885c820ad5592a409a3a8994            Ms.           NC
# 43184   p040307  363788b51d40d978fe276bcb1f8a2b35           Mrs.           CA
# 127083  p251806  4ba7c721133ef651ca54a03551746708            Ms.           CA
# 19090   p051126  5e52c92b7e3c472aad247a239d345543           Mrs.           NY
# 15126   p003874  178f6ae765cd4e0fb143a77c47fd65e2           Mrs.           OK
# 62232   p233127  424819801de22a60bba7d0f4354d0258            Ms.           MA
# 67303   p132832  bb6d6d054824fa01576ab38dfa2be160            Ms.           TX
# 127215  p174627  4ad7e280fddff889e1355cc9f29c3b89           Mrs.           FL
# 157771  p152491  e39abda057354c979c5b075cffbe5f88            Ms.           NV
# 122186  p196421  fcd9b003fc1891383f340a89da02a1a6           Mrs.           GA
# 146331  p058343  8e07a98deb1bc74c75b97521e05b1691            Ms.           OH
# 75560   p052326  e0c1aad1f71badeff703fadc15f57680           Mrs.           PA
# 132078  p187097  2d4a4d2d774e5c2fdd25b2ba0e7341f8           Mrs.           NC
# 84810   p165540  30f08fbe02eba5453c4ce2e857e88eb4            Ms.           CA
# 8636    p219330  258ef2e6ab5ce007ac6764ce15d261ba            Mr.           AL
# 21478   p126524  74f8690562c44fc88f65f845b9fe61d0           Mrs.           FL
# 20142   p009037  b8bf3507cee960d5fedcb27719df2d59           Mrs.           AL
# 33903   p040091  7a0a5de5ed94e7036946b1ac3eaa99d0            Ms.           TX
# 1156    p161033  efdc3cf14d136473c9f62becc00d4cec        Teacher           LA
# 35430   p085706  22c8184c4660f1c589bea061d14b7f35           Mrs.           GA
# 22088   p032018  45f16a103f1e00b7439861d4e0728a59           Mrs.           VA
# 110606  p244865  afa940a60a5c946afc08955ab7583f2f           Mrs.           IN
# 98411   p255626  e9908f2829c8c74e5c60f01b9cf0b2bc           Mrs.           NC
# 138318  p123575  18e7eaf7ac410143a1499aa1af61b90f           Mrs.           NC
# 119109  p146793  a5067ead1975d5e04baae371a5380b7e           Mrs.           AR
# 30818   p215384  e72d646bf9ca9b940bdc66260121c6f9            Ms.           CA
# 130530  p257171  add81cf8d0c457de1ac52057c140ee90            Mr.           NY
# 15493   p183139  3edf1305f38913e71fb824ddd87ca19c           Mrs.           WA
# 177938  p235099  fb961cd43218b42e06852a1e3bf82286            Ms.           TX
# 93864   p030703  7324b879d4f0efffa98c911d66b8a61f           Mrs.           CA
# 82196   p073721  0dd261f5280443f35cde6974660c3ccd            Ms.           FL
#
#        project_submitted_datetime project_grade_category  \
# 160221        2016-12-05 13:43:57          Grades PreK-2
# 140945        2016-10-25 09:22:10             Grades 6-8
# 21895         2016-08-31 12:03:56             Grades 6-8
# 45            2016-10-06 21:16:17          Grades PreK-2
# 172407        2016-07-11 01:10:09          Grades PreK-2
# 141660        2017-04-08 22:40:43             Grades 3-5
# 21147         2017-02-17 19:58:56             Grades 6-8
# 94142         2016-09-01 00:02:15             Grades 3-5
# 112489        2016-09-25 17:00:26          Grades PreK-2
# 158561        2016-11-17 18:18:56          Grades PreK-2
# 43184         2017-01-04 16:40:30             Grades 3-5
# 127083        2016-11-14 22:57:28          Grades PreK-2
# 19090         2016-05-23 15:46:02             Grades 6-8
# 15126         2016-10-17 09:49:27          Grades PreK-2
# 62232         2017-02-14 16:29:10          Grades PreK-2
# 67303         2016-10-05 21:05:38             Grades 3-5
# 127215        2017-01-18 10:59:05          Grades PreK-2
# 157771        2016-11-23 17:14:17             Grades 3-5
# 122186        2016-08-28 15:04:42          Grades PreK-2
# 146331        2016-08-06 13:05:20             Grades 3-5
# 75560         2016-10-07 18:27:02          Grades PreK-2
# 132078        2016-05-17 19:45:13             Grades 6-8
# 84810         2016-09-01 10:09:15            Grades 9-12
# 8636          2017-01-10 11:41:06             Grades 6-8
# 21478         2017-03-31 12:34:44          Grades PreK-2
# 20142         2017-03-09 15:36:20             Grades 3-5
# 33903         2016-09-18 22:10:40          Grades PreK-2
# 1156          2016-11-06 16:02:31             Grades 3-5
# 35430         2017-01-27 12:34:59            Grades 9-12
# 22088         2016-07-15 12:58:40          Grades PreK-2
# 110606        2017-04-06 16:58:25          Grades PreK-2
# 98411         2016-12-30 12:20:27          Grades PreK-2
# 138318        2017-04-01 07:17:06          Grades PreK-2
# 119109        2016-11-24 21:03:16          Grades PreK-2
# 30818         2016-08-04 16:52:57             Grades 3-5
# 130530        2016-05-29 17:54:14             Grades 6-8
# 15493         2016-08-24 22:35:39          Grades PreK-2
# 177938        2016-08-28 14:10:01          Grades PreK-2
# 93864         2016-08-01 20:11:35          Grades PreK-2
# 82196         2016-09-26 16:20:01            Grades 9-12
#
#                    project_subject_categories  \
# 160221                    Literacy & Language
# 140945      History & Civics, Health & Sports
# 21895                         Health & Sports
# 45        Literacy & Language, Math & Science
# 172407                         Math & Science
# 141660     Literacy & Language, Special Needs
# 21147      Literacy & Language, Special Needs
# 94142                          Math & Science
# 112489                        Health & Sports
# 158561                    Literacy & Language
# 43184                     Literacy & Language
# 127083  Literacy & Language, Applied Learning
# 19090                          Math & Science
# 15126                           Special Needs
# 62232                     Literacy & Language
# 67303                         Health & Sports
# 127215     Literacy & Language, Special Needs
# 157771    Math & Science, Literacy & Language
# 122186                       Applied Learning
# 146331                        Health & Sports
# 75560                     Literacy & Language
# 132078          Math & Science, Special Needs
# 84810                     Literacy & Language
# 8636                         Music & The Arts
# 21478                          Math & Science
# 20142                          Math & Science
# 33903     Literacy & Language, Math & Science
# 1156      Literacy & Language, Math & Science
# 35430      Literacy & Language, Special Needs
# 22088   Literacy & Language, Applied Learning
# 110606                    Literacy & Language
# 98411                           Special Needs
# 138318    Math & Science, Literacy & Language
# 119109                       History & Civics
# 30818                     Literacy & Language
# 130530                        Health & Sports
# 15493     Literacy & Language, Math & Science
# 177938   Health & Sports, Literacy & Language
# 93864                         Health & Sports
# 82196                     Literacy & Language
#
#                        project_subject_subcategories  \
# 160221                                 ESL, Literacy
# 140945              Civics & Government, Team Sports
# 21895                 Health & Wellness, Team Sports
# 45                             Literacy, Mathematics
# 172407                                   Mathematics
# 141660           Literature & Writing, Special Needs
# 21147                        Literacy, Special Needs
# 94142                                    Mathematics
# 112489                             Health & Wellness
# 158561                Literacy, Literature & Writing
# 43184                                       Literacy
# 127083                  Literacy, Parent Involvement
# 19090   Environmental Science, Health & Life Science
# 15126                                  Special Needs
# 62232                                       Literacy
# 67303                              Health & Wellness
# 127215                       Literacy, Special Needs
# 157771        Applied Sciences, Literature & Writing
# 122186                             Early Development
# 146331                             Health & Wellness
# 75560                                       Literacy
# 132078          Health & Life Science, Special Needs
# 84810                                       Literacy
# 8636                                           Music
# 21478                  Applied Sciences, Mathematics
# 20142                                    Mathematics
# 33903                          Literacy, Mathematics
# 1156                  Foreign Languages, Mathematics
# 35430                        Literacy, Special Needs
# 22088                                Literacy, Other
# 110606                                      Literacy
# 98411                                  Special Needs
# 138318               Health & Life Science, Literacy
# 119109                 Economics, Financial Literacy
# 30818                           Literature & Writing
# 130530                                   Team Sports
# 15493              Literature & Writing, Mathematics
# 177938                   Health & Wellness, Literacy
# 93864               Gym & Fitness, Health & Wellness
# 82196                 Literacy, Literature & Writing
#
#                                             project_title  \
# 160221   Educational Support for English Learners at Home
# 140945              Wanted: Projector for Hungry Learners
# 21895   Soccer Equipment for AWESOME Middle School Stu...
# 45                                 Techie Kindergarteners
# 172407                             Interactive Math Tools
# 141660  Flexible Seating for Mrs. Jarvis' Terrific Thi...
# 21147   Chromebooks for Special Education Reading Program
# 94142                               It's the 21st Century
# 112489                    Targeting More Success in Class
# 158561    Just For the Love of Reading--\r\nPure Pleasure
# 43184                               Reading Changes Lives
# 127083  Elevating Academics and Parent Rapports Throug...
# 19090                   Building Life Science Experiences
# 15126                      Everyone deserves to be heard!
# 62232                       TABLETS CAN SHOW US THE WORLD
# 67303                                Making Recess Active
# 127215                 Making Great LEAP's With Leapfrog!
# 157771        Technology Teaches Tomorrow's Talents Today
# 122186                                          Test Time
# 146331                        Wiggling Our Way to Success
# 75560                    Magic Carpet Ride in Our Library
# 132078          From Sitting to Standing in the Classroom
# 84810                     Books for Budding Intellectuals
# 8636                Instrumental Power: Conquering STEAM!
# 21478   S.T.E.A.M. Challenges(Science Technology Engin...
# 20142                                       Math Masters!
# 33903                                      Techy Teaching
# 1156               4th Grade French Immersion Class Ipads
# 35430                      Hands-On Language and Literacy
# 22088                     Basic Classroom Supplies Needed
# 110606    2nd Grade Explores the World of Charlotte's Web
# 98411                     An All Inclusive Learning Space
# 138318                        Learning Facts From Fiction
# 119109    Computing Our Way to Financial Literacy! Part 2
# 30818                                  \"Have A Ball!!!\"
# 130530                                    Put Me In Coach
# 15493     Inquiry Based Discovery Through Laptop Learning
# 177938             Target Our Kids With A Printer And Ink
# 93864   Kinders Inspired to be on Target in Fitness Pa...
# 82196                Engaging Students through Technology
#
#                                           project_essay_1  \
# 160221  My students are English learners that are work...
# 140945  Our students arrive to our school eager to lea...
# 21895   \r\n\"True champions aren't always the ones th...
# 45      I work at a unique school filled with both ESL...
# 172407  Our second grade classroom next year will be m...
# 141660  I will be moving from 2nd grade to 3rd grade a...
# 21147   My students are a dynamic and very energetic g...
# 94142   Not only do our students struggle with poverty...
# 112489  My students are enthusiastic and inquisitive l...
# 158561  Over 95% of my students are on free or reduced...
# 43184   \"There are many little ways to enlarge your w...
# 127083  All of our students receive free breakfast, lu...
# 19090   My students are always working on new projects...
# 15126   I teach in a small school district in central ...
# 62232   My students are my babies...I want the world f...
# 67303   Located in West Dallas, my students face sever...
# 127215  My Preschool children, ages 3-5 years old with...
# 157771  My students are special because they come from...
# 122186  I teach at a Title I school in a low-income ar...
# 146331  We are apart of an urban district and many of ...
# 75560   The students in our school come from diverse b...
# 132078  My students walk into school every day full of...
# 84810   Every day in my English classroom, we work to ...
# 8636    100% of our musical students eat free breakfas...
# 21478   This year, I am teaching in an EFL (Extended F...
# 20142   My students are highly motivated to succeed. U...
# 33903   I teach 22 bright 5 and 6 year olds. My studen...
# 1156    My students spend most of their day learning f...
# 35430   My students all have a primary diagnosis of au...
# 22088   I have an awesome group of 24 students any tea...
# 110606  I work in a low income school on the east side...
# 98411   As a teacher in a low income/ high-poverty sch...
# 138318  My school is Title I and located in a small No...
# 119109  My students are the most talented, interesting...
# 30818   My students mainly come from extremely low-inc...
# 130530  Our school, located in the South Bronx, is in ...
# 15493   I will be teaching first grade this year with ...
# 177938  My students are 4 and 5 year old's who love to...
# 93864   I teach a group of culturally diverse transiti...
# 82196   I work at a magnet school, located in the midd...
#
#                                           project_essay_2 project_essay_3  \
# 160221  \"The limits of your language are the limits o...             NaN
# 140945  The projector we need for our school is very c...             NaN
# 21895   The students on the campus come to school know...             NaN
# 45      My students live in high poverty conditions wi...             NaN
# 172407  For many students, math is a subject that does...             NaN
# 141660  These flexible seating options will allow my s...             NaN
# 21147   My students are an engaging and active group o...             NaN
# 94142   My students need 4 iPads, the latest technolog...             NaN
# 112489  My second graders need extra activity time dur...             NaN
# 158561  Reading is Fundamental! My students will read ...             NaN
# 43184   I've had 8 sets of students enjoy the books in...             NaN
# 127083  With three chromebooks, I can teach the Common...             NaN
# 19090   My Spanish Dual Language students are always r...             NaN
# 15126   My students are smart, creative, and also have...             NaN
# 62232   Having this computer in the classroom would pr...             NaN
# 67303   Due to the size of our school, and the tiny na...             NaN
# 127215  Having a set of Leapfrog iPads and educational...             NaN
# 157771  Classroom ChromebookCar\r\n\r\nMy name is Shan...             NaN
# 122186  My 2nd grade students will benefit from having...             NaN
# 146331  Many of my students struggle to sit still for ...             NaN
# 75560   Each week our students love visiting the schoo...             NaN
# 132078  I want to purchase desks in my classroom that ...             NaN
# 84810   My students need books that interest them so t...             NaN
# 8636    We need classroom instruments for our band pro...             NaN
# 21478   I will use these items to create S.T.E.A.M. bi...             NaN
# 20142   These math games will help reinforce the skill...             NaN
# 33903   The iPads will be effectively used to improve ...             NaN
# 1156    The iPads will also be used to enhance the stu...             NaN
# 35430   Children with autism struggle in core deficit ...             NaN
# 22088   My students need basic school supplies such as...             NaN
# 110606  Many of the students in my class have begun re...             NaN
# 98411   My class is filled with sweet students that ha...             NaN
# 138318  My students often repeat things they hear othe...             NaN
# 119109  I am requesting one Dell Touch-screen  compute...             NaN
# 30818   I am excited to be experimenting with alternat...             NaN
# 130530  Baseball gloves, are the most fundamental part...             NaN
# 15493   My school places a large focus on inquiry base...             NaN
# 177938  My students have asked for pictures in color. ...             NaN
# 93864   My students inspire me to help them be more ac...             NaN
# 82196   My desire is to have a class set of tablets (2...             NaN
#
#        project_essay_4                           project_resource_summary  \
# 160221             NaN  My students need opportunities to practice beg...
# 140945             NaN  My students need a projector to help with view...
# 21895              NaN  My students need shine guards, athletic socks,...
# 45                 NaN  My students need to engage in Reading and Math...
# 172407             NaN  My students need hands on practice in mathemat...
# 141660             NaN  My students need movement to be successful. Be...
# 21147              NaN  My students need some dependable laptops for d...
# 94142              NaN  My students need ipads to help them access a w...
# 112489             NaN  My students need three devices and three manag...
# 158561             NaN  My students need great books to use during Ind...
# 43184              NaN  My students need books by their favorite autho...
# 127083             NaN  My students need paper, three chromebooks, and...
# 19090              NaN  My students need 3D and 4D life science activi...
# 15126              NaN  My students need access to technology that wil...
# 62232              NaN  My students need 5 tablets for our classroom t...
# 67303              NaN  My students need activities to play during rec...
# 127215             NaN  My students need 2 LeapPad that will engage th...
# 157771             NaN  My students need Chromebooks to publish writte...
# 122186             NaN  My students need privacy partitions to use whi...
# 146331             NaN  My students need 7 Hokki stools to encourage a...
# 75560              NaN  My students need carpet in our library to brig...
# 132078             NaN  My students need desks to stand at and be able...
# 84810              NaN  My students need books so that they can become...
# 8636               NaN  My students need these instruments to give the...
# 21478              NaN  My students need building materials, such as g...
# 20142              NaN  My students need the learning centers and mult...
# 33903              NaN  My students need 2 ipad minis to enhance learn...
# 1156               NaN  My students need Ipads to work in smaller grou...
# 35430              NaN  My students need to increase language and lite...
# 22088              NaN  My students need basic school supplies such as...
# 110606             NaN  My students need a class set of the book Charl...
# 98411              NaN  My students need materials that help make them...
# 138318             NaN  My students need nonfiction readers and a new ...
# 119109             NaN  My students need a new desktop computer to use...
# 30818              NaN  My students need alternative seating, to incre...
# 130530             NaN  My students need baseball gloves that fit for ...
# 15493              NaN  My students need a laptop to use for research,...
# 177938             NaN  My students need a color printer, ink for our ...
# 93864              NaN  My students need fitness equipment to build th...
# 82196              NaN  My students need a class set of tablets to eng...
#
#         teacher_number_of_previously_posted_projects  project_is_approved  \
# 160221                                             0                    0
# 140945                                             7                    1
# 21895                                              1                    0
# 45                                                 4                    1
# 172407                                             1                    1
# 141660                                             1                    1
# 21147                                              1                    1
# 94142                                              7                    1
# 112489                                            28                    1
# 158561                                            36                    1
# 43184                                             37                    1
# 127083                                            32                    1
# 19090                                              5                    0
# 15126                                             30                    1
# 62232                                             15                    0
# 67303                                              3                    1
# 127215                                             1                    1
# 157771                                             0                    1
# 122186                                             0                    1
# 146331                                             9                    1
# 75560                                             23                    1
# 132078                                             0                    1
# 84810                                              0                    0
# 8636                                               2                    1
# 21478                                              0                    1
# 20142                                             11                    0
# 33903                                              2                    1
# 1156                                               2                    1
# 35430                                              5                    0
# 22088                                              0                    1
# 110606                                             0                    1
# 98411                                              6                    1
# 138318                                            48                    1
# 119109                                            84                    1
# 30818                                              0                    1
# 130530                                            22                    1
# 15493                                             13                    1
# 177938                                            30                    1
# 93864                                             14                    1
# 82196                                              0                    1
#
#         project_subject_categories_updated
# 160221                   literacy_language
# 140945        history_civics health_sports
# 21895                        health_sports
# 45          literacy_language math_science
# 172407                        math_science
# 141660     literacy_language special_needs
# 21147      literacy_language special_needs
# 94142                         math_science
# 112489                       health_sports
# 158561                   literacy_language
# 43184                    literacy_language
# 127083  literacy_language applied_learning
# 19090                         math_science
# 15126                        special_needs
# 62232                    literacy_language
# 67303                        health_sports
# 127215     literacy_language special_needs
# 157771      math_science literacy_language
# 122186                    applied_learning
# 146331                       health_sports
# 75560                    literacy_language
# 132078          math_science special_needs
# 84810                    literacy_language
# 8636                        music_the_arts
# 21478                         math_science
# 20142                         math_science
# 33903       literacy_language math_science
# 1156        literacy_language math_science
# 35430      literacy_language special_needs
# 22088   literacy_language applied_learning
# 110606                   literacy_language
# 98411                        special_needs
# 138318      math_science literacy_language
# 119109                      history_civics
# 30818                    literacy_language
# 130530                       health_sports
# 15493       literacy_language math_science
# 177938     health_sports literacy_language
# 93864                        health_sports
# 82196                    literacy_language

# %%
# Working on subject subcategory
# Working on project subject category
projct_subject_subcategory=train_data_df["project_subject_subcategories"]
projct_subject_subcategory.head(20)
# Out:
# 160221                                   ESL, Literacy
# 140945                Civics & Government, Team Sports
# 21895                   Health & Wellness, Team Sports
# 45                               Literacy, Mathematics
# 172407                                     Mathematics
# 141660             Literature & Writing, Special Needs
# 21147                          Literacy, Special Needs
# 94142                                      Mathematics
# 112489                               Health & Wellness
# 158561                  Literacy, Literature & Writing
# 43184                                         Literacy
# 127083                    Literacy, Parent Involvement
# 19090     Environmental Science, Health & Life Science
# 15126                                    Special Needs
# 62232                                         Literacy
# 67303                                Health & Wellness
# 127215                         Literacy, Special Needs
# 157771          Applied Sciences, Literature & Writing
# 122186                               Early Development
# 146331                               Health & Wellness
# Name: project_subject_subcategories, dtype: object

# %%
'''
Formatting of data in the following way
1) ESL, Literacy to ESL_Literacy
2) Civics & Government, Team Sportsto Civics_Government Team_Sports
'''
# Out:
# '\nFormatting of data in the following way\n1) ESL, Literacy to ESL_Literacy\n2) Civics & Government, Team Sportsto Civics_Government Team_Sports\n'

# %%
# Remove ampersands, split the strings by commas
train_data_df['project_subject_subcategories_updated'] = train_data_df['project_subject_subcategories'].str.replace("&", "").str.split(",")

# Remove leading/trailing spaces, convert to lowercase, replace spaces with underscores
train_data_df['project_subject_subcategories_updated'] = train_data_df['project_subject_subcategories_updated'].apply(lambda words: [word.strip().lower().replace(" ", "_") for word in words])

# Concatenate the categories into a single string
train_data_df['project_subject_subcategories_updated'] = train_data_df['project_subject_subcategories_updated'].apply(lambda words: " ".join(words))
# Replace double underscores with single underscores
train_data_df['project_subject_subcategories_updated'] = train_data_df['project_subject_subcategories_updated'].str.replace("__", "_")
train_data_df.head(40)
# Out:
#              id                        teacher_id teacher_prefix school_state  \
# 160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.           IN
# 140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.           FL
# 21895   p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.           AZ
# 45      p246581  f3cb9bffbba169bef1a77b243e620b60           Mrs.           KY
# 172407  p104768  be1f7507a41f8479dc06f047086a39ec           Mrs.           TX
# 141660  p154343  a50a390e8327a95b77b9e495b58b9a6e           Mrs.           FL
# 21147   p099819  9b40170bfa65e399981717ee8731efc3           Mrs.           CT
# 94142   p092424  5bfd3d12fae3d2fe88684bbac570c9d2            Ms.           GA
# 112489  p045029  487448f5226005d08d36bdd75f095b31           Mrs.           SC
# 158561  p001713  140eeac1885c820ad5592a409a3a8994            Ms.           NC
# 43184   p040307  363788b51d40d978fe276bcb1f8a2b35           Mrs.           CA
# 127083  p251806  4ba7c721133ef651ca54a03551746708            Ms.           CA
# 19090   p051126  5e52c92b7e3c472aad247a239d345543           Mrs.           NY
# 15126   p003874  178f6ae765cd4e0fb143a77c47fd65e2           Mrs.           OK
# 62232   p233127  424819801de22a60bba7d0f4354d0258            Ms.           MA
# 67303   p132832  bb6d6d054824fa01576ab38dfa2be160            Ms.           TX
# 127215  p174627  4ad7e280fddff889e1355cc9f29c3b89           Mrs.           FL
# 157771  p152491  e39abda057354c979c5b075cffbe5f88            Ms.           NV
# 122186  p196421  fcd9b003fc1891383f340a89da02a1a6           Mrs.           GA
# 146331  p058343  8e07a98deb1bc74c75b97521e05b1691            Ms.           OH
# 75560   p052326  e0c1aad1f71badeff703fadc15f57680           Mrs.           PA
# 132078  p187097  2d4a4d2d774e5c2fdd25b2ba0e7341f8           Mrs.           NC
# 84810   p165540  30f08fbe02eba5453c4ce2e857e88eb4            Ms.           CA
# 8636    p219330  258ef2e6ab5ce007ac6764ce15d261ba            Mr.           AL
# 21478   p126524  74f8690562c44fc88f65f845b9fe61d0           Mrs.           FL
# 20142   p009037  b8bf3507cee960d5fedcb27719df2d59           Mrs.           AL
# 33903   p040091  7a0a5de5ed94e7036946b1ac3eaa99d0            Ms.           TX
# 1156    p161033  efdc3cf14d136473c9f62becc00d4cec        Teacher           LA
# 35430   p085706  22c8184c4660f1c589bea061d14b7f35           Mrs.           GA
# 22088   p032018  45f16a103f1e00b7439861d4e0728a59           Mrs.           VA
# 110606  p244865  afa940a60a5c946afc08955ab7583f2f           Mrs.           IN
# 98411   p255626  e9908f2829c8c74e5c60f01b9cf0b2bc           Mrs.           NC
# 138318  p123575  18e7eaf7ac410143a1499aa1af61b90f           Mrs.           NC
# 119109  p146793  a5067ead1975d5e04baae371a5380b7e           Mrs.           AR
# 30818   p215384  e72d646bf9ca9b940bdc66260121c6f9            Ms.           CA
# 130530  p257171  add81cf8d0c457de1ac52057c140ee90            Mr.           NY
# 15493   p183139  3edf1305f38913e71fb824ddd87ca19c           Mrs.           WA
# 177938  p235099  fb961cd43218b42e06852a1e3bf82286            Ms.           TX
# 93864   p030703  7324b879d4f0efffa98c911d66b8a61f           Mrs.           CA
# 82196   p073721  0dd261f5280443f35cde6974660c3ccd            Ms.           FL
#
#        project_submitted_datetime project_grade_category  \
# 160221        2016-12-05 13:43:57          Grades PreK-2
# 140945        2016-10-25 09:22:10             Grades 6-8
# 21895         2016-08-31 12:03:56             Grades 6-8
# 45            2016-10-06 21:16:17          Grades PreK-2
# 172407        2016-07-11 01:10:09          Grades PreK-2
# 141660        2017-04-08 22:40:43             Grades 3-5
# 21147         2017-02-17 19:58:56             Grades 6-8
# 94142         2016-09-01 00:02:15             Grades 3-5
# 112489        2016-09-25 17:00:26          Grades PreK-2
# 158561        2016-11-17 18:18:56          Grades PreK-2
# 43184         2017-01-04 16:40:30             Grades 3-5
# 127083        2016-11-14 22:57:28          Grades PreK-2
# 19090         2016-05-23 15:46:02             Grades 6-8
# 15126         2016-10-17 09:49:27          Grades PreK-2
# 62232         2017-02-14 16:29:10          Grades PreK-2
# 67303         2016-10-05 21:05:38             Grades 3-5
# 127215        2017-01-18 10:59:05          Grades PreK-2
# 157771        2016-11-23 17:14:17             Grades 3-5
# 122186        2016-08-28 15:04:42          Grades PreK-2
# 146331        2016-08-06 13:05:20             Grades 3-5
# 75560         2016-10-07 18:27:02          Grades PreK-2
# 132078        2016-05-17 19:45:13             Grades 6-8
# 84810         2016-09-01 10:09:15            Grades 9-12
# 8636          2017-01-10 11:41:06             Grades 6-8
# 21478         2017-03-31 12:34:44          Grades PreK-2
# 20142         2017-03-09 15:36:20             Grades 3-5
# 33903         2016-09-18 22:10:40          Grades PreK-2
# 1156          2016-11-06 16:02:31             Grades 3-5
# 35430         2017-01-27 12:34:59            Grades 9-12
# 22088         2016-07-15 12:58:40          Grades PreK-2
# 110606        2017-04-06 16:58:25          Grades PreK-2
# 98411         2016-12-30 12:20:27          Grades PreK-2
# 138318        2017-04-01 07:17:06          Grades PreK-2
# 119109        2016-11-24 21:03:16          Grades PreK-2
# 30818         2016-08-04 16:52:57             Grades 3-5
# 130530        2016-05-29 17:54:14             Grades 6-8
# 15493         2016-08-24 22:35:39          Grades PreK-2
# 177938        2016-08-28 14:10:01          Grades PreK-2
# 93864         2016-08-01 20:11:35          Grades PreK-2
# 82196         2016-09-26 16:20:01            Grades 9-12
#
#                    project_subject_categories  \
# 160221                    Literacy & Language
# 140945      History & Civics, Health & Sports
# 21895                         Health & Sports
# 45        Literacy & Language, Math & Science
# 172407                         Math & Science
# 141660     Literacy & Language, Special Needs
# 21147      Literacy & Language, Special Needs
# 94142                          Math & Science
# 112489                        Health & Sports
# 158561                    Literacy & Language
# 43184                     Literacy & Language
# 127083  Literacy & Language, Applied Learning
# 19090                          Math & Science
# 15126                           Special Needs
# 62232                     Literacy & Language
# 67303                         Health & Sports
# 127215     Literacy & Language, Special Needs
# 157771    Math & Science, Literacy & Language
# 122186                       Applied Learning
# 146331                        Health & Sports
# 75560                     Literacy & Language
# 132078          Math & Science, Special Needs
# 84810                     Literacy & Language
# 8636                         Music & The Arts
# 21478                          Math & Science
# 20142                          Math & Science
# 33903     Literacy & Language, Math & Science
# 1156      Literacy & Language, Math & Science
# 35430      Literacy & Language, Special Needs
# 22088   Literacy & Language, Applied Learning
# 110606                    Literacy & Language
# 98411                           Special Needs
# 138318    Math & Science, Literacy & Language
# 119109                       History & Civics
# 30818                     Literacy & Language
# 130530                        Health & Sports
# 15493     Literacy & Language, Math & Science
# 177938   Health & Sports, Literacy & Language
# 93864                         Health & Sports
# 82196                     Literacy & Language
#
#                        project_subject_subcategories  \
# 160221                                 ESL, Literacy
# 140945              Civics & Government, Team Sports
# 21895                 Health & Wellness, Team Sports
# 45                             Literacy, Mathematics
# 172407                                   Mathematics
# 141660           Literature & Writing, Special Needs
# 21147                        Literacy, Special Needs
# 94142                                    Mathematics
# 112489                             Health & Wellness
# 158561                Literacy, Literature & Writing
# 43184                                       Literacy
# 127083                  Literacy, Parent Involvement
# 19090   Environmental Science, Health & Life Science
# 15126                                  Special Needs
# 62232                                       Literacy
# 67303                              Health & Wellness
# 127215                       Literacy, Special Needs
# 157771        Applied Sciences, Literature & Writing
# 122186                             Early Development
# 146331                             Health & Wellness
# 75560                                       Literacy
# 132078          Health & Life Science, Special Needs
# 84810                                       Literacy
# 8636                                           Music
# 21478                  Applied Sciences, Mathematics
# 20142                                    Mathematics
# 33903                          Literacy, Mathematics
# 1156                  Foreign Languages, Mathematics
# 35430                        Literacy, Special Needs
# 22088                                Literacy, Other
# 110606                                      Literacy
# 98411                                  Special Needs
# 138318               Health & Life Science, Literacy
# 119109                 Economics, Financial Literacy
# 30818                           Literature & Writing
# 130530                                   Team Sports
# 15493              Literature & Writing, Mathematics
# 177938                   Health & Wellness, Literacy
# 93864               Gym & Fitness, Health & Wellness
# 82196                 Literacy, Literature & Writing
#
#                                             project_title  \
# 160221   Educational Support for English Learners at Home
# 140945              Wanted: Projector for Hungry Learners
# 21895   Soccer Equipment for AWESOME Middle School Stu...
# 45                                 Techie Kindergarteners
# 172407                             Interactive Math Tools
# 141660  Flexible Seating for Mrs. Jarvis' Terrific Thi...
# 21147   Chromebooks for Special Education Reading Program
# 94142                               It's the 21st Century
# 112489                    Targeting More Success in Class
# 158561    Just For the Love of Reading--\r\nPure Pleasure
# 43184                               Reading Changes Lives
# 127083  Elevating Academics and Parent Rapports Throug...
# 19090                   Building Life Science Experiences
# 15126                      Everyone deserves to be heard!
# 62232                       TABLETS CAN SHOW US THE WORLD
# 67303                                Making Recess Active
# 127215                 Making Great LEAP's With Leapfrog!
# 157771        Technology Teaches Tomorrow's Talents Today
# 122186                                          Test Time
# 146331                        Wiggling Our Way to Success
# 75560                    Magic Carpet Ride in Our Library
# 132078          From Sitting to Standing in the Classroom
# 84810                     Books for Budding Intellectuals
# 8636                Instrumental Power: Conquering STEAM!
# 21478   S.T.E.A.M. Challenges(Science Technology Engin...
# 20142                                       Math Masters!
# 33903                                      Techy Teaching
# 1156               4th Grade French Immersion Class Ipads
# 35430                      Hands-On Language and Literacy
# 22088                     Basic Classroom Supplies Needed
# 110606    2nd Grade Explores the World of Charlotte's Web
# 98411                     An All Inclusive Learning Space
# 138318                        Learning Facts From Fiction
# 119109    Computing Our Way to Financial Literacy! Part 2
# 30818                                  \"Have A Ball!!!\"
# 130530                                    Put Me In Coach
# 15493     Inquiry Based Discovery Through Laptop Learning
# 177938             Target Our Kids With A Printer And Ink
# 93864   Kinders Inspired to be on Target in Fitness Pa...
# 82196                Engaging Students through Technology
#
#                                           project_essay_1  \
# 160221  My students are English learners that are work...
# 140945  Our students arrive to our school eager to lea...
# 21895   \r\n\"True champions aren't always the ones th...
# 45      I work at a unique school filled with both ESL...
# 172407  Our second grade classroom next year will be m...
# 141660  I will be moving from 2nd grade to 3rd grade a...
# 21147   My students are a dynamic and very energetic g...
# 94142   Not only do our students struggle with poverty...
# 112489  My students are enthusiastic and inquisitive l...
# 158561  Over 95% of my students are on free or reduced...
# 43184   \"There are many little ways to enlarge your w...
# 127083  All of our students receive free breakfast, lu...
# 19090   My students are always working on new projects...
# 15126   I teach in a small school district in central ...
# 62232   My students are my babies...I want the world f...
# 67303   Located in West Dallas, my students face sever...
# 127215  My Preschool children, ages 3-5 years old with...
# 157771  My students are special because they come from...
# 122186  I teach at a Title I school in a low-income ar...
# 146331  We are apart of an urban district and many of ...
# 75560   The students in our school come from diverse b...
# 132078  My students walk into school every day full of...
# 84810   Every day in my English classroom, we work to ...
# 8636    100% of our musical students eat free breakfas...
# 21478   This year, I am teaching in an EFL (Extended F...
# 20142   My students are highly motivated to succeed. U...
# 33903   I teach 22 bright 5 and 6 year olds. My studen...
# 1156    My students spend most of their day learning f...
# 35430   My students all have a primary diagnosis of au...
# 22088   I have an awesome group of 24 students any tea...
# 110606  I work in a low income school on the east side...
# 98411   As a teacher in a low income/ high-poverty sch...
# 138318  My school is Title I and located in a small No...
# 119109  My students are the most talented, interesting...
# 30818   My students mainly come from extremely low-inc...
# 130530  Our school, located in the South Bronx, is in ...
# 15493   I will be teaching first grade this year with ...
# 177938  My students are 4 and 5 year old's who love to...
# 93864   I teach a group of culturally diverse transiti...
# 82196   I work at a magnet school, located in the midd...
#
#                                           project_essay_2 project_essay_3  \
# 160221  \"The limits of your language are the limits o...             NaN
# 140945  The projector we need for our school is very c...             NaN
# 21895   The students on the campus come to school know...             NaN
# 45      My students live in high poverty conditions wi...             NaN
# 172407  For many students, math is a subject that does...             NaN
# 141660  These flexible seating options will allow my s...             NaN
# 21147   My students are an engaging and active group o...             NaN
# 94142   My students need 4 iPads, the latest technolog...             NaN
# 112489  My second graders need extra activity time dur...             NaN
# 158561  Reading is Fundamental! My students will read ...             NaN
# 43184   I've had 8 sets of students enjoy the books in...             NaN
# 127083  With three chromebooks, I can teach the Common...             NaN
# 19090   My Spanish Dual Language students are always r...             NaN
# 15126   My students are smart, creative, and also have...             NaN
# 62232   Having this computer in the classroom would pr...             NaN
# 67303   Due to the size of our school, and the tiny na...             NaN
# 127215  Having a set of Leapfrog iPads and educational...             NaN
# 157771  Classroom ChromebookCar\r\n\r\nMy name is Shan...             NaN
# 122186  My 2nd grade students will benefit from having...             NaN
# 146331  Many of my students struggle to sit still for ...             NaN
# 75560   Each week our students love visiting the schoo...             NaN
# 132078  I want to purchase desks in my classroom that ...             NaN
# 84810   My students need books that interest them so t...             NaN
# 8636    We need classroom instruments for our band pro...             NaN
# 21478   I will use these items to create S.T.E.A.M. bi...             NaN
# 20142   These math games will help reinforce the skill...             NaN
# 33903   The iPads will be effectively used to improve ...             NaN
# 1156    The iPads will also be used to enhance the stu...             NaN
# 35430   Children with autism struggle in core deficit ...             NaN
# 22088   My students need basic school supplies such as...             NaN
# 110606  Many of the students in my class have begun re...             NaN
# 98411   My class is filled with sweet students that ha...             NaN
# 138318  My students often repeat things they hear othe...             NaN
# 119109  I am requesting one Dell Touch-screen  compute...             NaN
# 30818   I am excited to be experimenting with alternat...             NaN
# 130530  Baseball gloves, are the most fundamental part...             NaN
# 15493   My school places a large focus on inquiry base...             NaN
# 177938  My students have asked for pictures in color. ...             NaN
# 93864   My students inspire me to help them be more ac...             NaN
# 82196   My desire is to have a class set of tablets (2...             NaN
#
#        project_essay_4                           project_resource_summary  \
# 160221             NaN  My students need opportunities to practice beg...
# 140945             NaN  My students need a projector to help with view...
# 21895              NaN  My students need shine guards, athletic socks,...
# 45                 NaN  My students need to engage in Reading and Math...
# 172407             NaN  My students need hands on practice in mathemat...
# 141660             NaN  My students need movement to be successful. Be...
# 21147              NaN  My students need some dependable laptops for d...
# 94142              NaN  My students need ipads to help them access a w...
# 112489             NaN  My students need three devices and three manag...
# 158561             NaN  My students need great books to use during Ind...
# 43184              NaN  My students need books by their favorite autho...
# 127083             NaN  My students need paper, three chromebooks, and...
# 19090              NaN  My students need 3D and 4D life science activi...
# 15126              NaN  My students need access to technology that wil...
# 62232              NaN  My students need 5 tablets for our classroom t...
# 67303              NaN  My students need activities to play during rec...
# 127215             NaN  My students need 2 LeapPad that will engage th...
# 157771             NaN  My students need Chromebooks to publish writte...
# 122186             NaN  My students need privacy partitions to use whi...
# 146331             NaN  My students need 7 Hokki stools to encourage a...
# 75560              NaN  My students need carpet in our library to brig...
# 132078             NaN  My students need desks to stand at and be able...
# 84810              NaN  My students need books so that they can become...
# 8636               NaN  My students need these instruments to give the...
# 21478              NaN  My students need building materials, such as g...
# 20142              NaN  My students need the learning centers and mult...
# 33903              NaN  My students need 2 ipad minis to enhance learn...
# 1156               NaN  My students need Ipads to work in smaller grou...
# 35430              NaN  My students need to increase language and lite...
# 22088              NaN  My students need basic school supplies such as...
# 110606             NaN  My students need a class set of the book Charl...
# 98411              NaN  My students need materials that help make them...
# 138318             NaN  My students need nonfiction readers and a new ...
# 119109             NaN  My students need a new desktop computer to use...
# 30818              NaN  My students need alternative seating, to incre...
# 130530             NaN  My students need baseball gloves that fit for ...
# 15493              NaN  My students need a laptop to use for research,...
# 177938             NaN  My students need a color printer, ink for our ...
# 93864              NaN  My students need fitness equipment to build th...
# 82196              NaN  My students need a class set of tablets to eng...
#
#         teacher_number_of_previously_posted_projects  project_is_approved  \
# 160221                                             0                    0
# 140945                                             7                    1
# 21895                                              1                    0
# 45                                                 4                    1
# 172407                                             1                    1
# 141660                                             1                    1
# 21147                                              1                    1
# 94142                                              7                    1
# 112489                                            28                    1
# 158561                                            36                    1
# 43184                                             37                    1
# 127083                                            32                    1
# 19090                                              5                    0
# 15126                                             30                    1
# 62232                                             15                    0
# 67303                                              3                    1
# 127215                                             1                    1
# 157771                                             0                    1
# 122186                                             0                    1
# 146331                                             9                    1
# 75560                                             23                    1
# 132078                                             0                    1
# 84810                                              0                    0
# 8636                                               2                    1
# 21478                                              0                    1
# 20142                                             11                    0
# 33903                                              2                    1
# 1156                                               2                    1
# 35430                                              5                    0
# 22088                                              0                    1
# 110606                                             0                    1
# 98411                                              6                    1
# 138318                                            48                    1
# 119109                                            84                    1
# 30818                                              0                    1
# 130530                                            22                    1
# 15493                                             13                    1
# 177938                                            30                    1
# 93864                                             14                    1
# 82196                                              0                    1
#
#         project_subject_categories_updated  \
# 160221                   literacy_language
# 140945        history_civics health_sports
# 21895                        health_sports
# 45          literacy_language math_science
# 172407                        math_science
# 141660     literacy_language special_needs
# 21147      literacy_language special_needs
# 94142                         math_science
# 112489                       health_sports
# 158561                   literacy_language
# 43184                    literacy_language
# 127083  literacy_language applied_learning
# 19090                         math_science
# 15126                        special_needs
# 62232                    literacy_language
# 67303                        health_sports
# 127215     literacy_language special_needs
# 157771      math_science literacy_language
# 122186                    applied_learning
# 146331                       health_sports
# 75560                    literacy_language
# 132078          math_science special_needs
# 84810                    literacy_language
# 8636                        music_the_arts
# 21478                         math_science
# 20142                         math_science
# 33903       literacy_language math_science
# 1156        literacy_language math_science
# 35430      literacy_language special_needs
# 22088   literacy_language applied_learning
# 110606                   literacy_language
# 98411                        special_needs
# 138318      math_science literacy_language
# 119109                      history_civics
# 30818                    literacy_language
# 130530                       health_sports
# 15493       literacy_language math_science
# 177938     health_sports literacy_language
# 93864                        health_sports
# 82196                    literacy_language
#
#             project_subject_subcategories_updated
# 160221                               esl literacy
# 140945              civics_government team_sports
# 21895                 health_wellness team_sports
# 45                           literacy mathematics
# 172407                                mathematics
# 141660           literature_writing special_needs
# 21147                      literacy special_needs
# 94142                                 mathematics
# 112489                            health_wellness
# 158561                literacy literature_writing
# 43184                                    literacy
# 127083                literacy parent_involvement
# 19090   environmental_science health_life_science
# 15126                               special_needs
# 62232                                    literacy
# 67303                             health_wellness
# 127215                     literacy special_needs
# 157771        applied_sciences literature_writing
# 122186                          early_development
# 146331                            health_wellness
# 75560                                    literacy
# 132078          health_life_science special_needs
# 84810                                    literacy
# 8636                                        music
# 21478                applied_sciences mathematics
# 20142                                 mathematics
# 33903                        literacy mathematics
# 1156                foreign_languages mathematics
# 35430                      literacy special_needs
# 22088                              literacy other
# 110606                                   literacy
# 98411                               special_needs
# 138318               health_life_science literacy
# 119109               economics financial_literacy
# 30818                          literature_writing
# 130530                                team_sports
# 15493              literature_writing mathematics
# 177938                   health_wellness literacy
# 93864                 gym_fitness health_wellness
# 82196                 literacy literature_writing

# %%
# Working on project grade category
grade=train_data_df['project_grade_category']
grade.head(10)
# Out:
# 160221    Grades PreK-2
# 140945       Grades 6-8
# 21895        Grades 6-8
# 45        Grades PreK-2
# 172407    Grades PreK-2
# 141660       Grades 3-5
# 21147        Grades 6-8
# 94142        Grades 3-5
# 112489    Grades PreK-2
# 158561    Grades PreK-2
# Name: project_grade_category, dtype: object

# %%
train_data_df['project_grade_category'].value_counts()
# Out:
# Grades PreK-2    44225
# Grades 3-5       37135
# Grades 6-8       16923
# Grades 9-12      10962
# Name: project_grade_category, dtype: int64

# %%
'''
Formatting of data in the following way
1) Grades PreK-2 to grade_prel_2
2) Grades 3-5 to grade_3_5
3) Grades 6-8 to grade_6_8
4)Grades 9-12 to grade_9_12
'''
# Out:
# '\nFormatting of data in the following way\n1) Grades PreK-2 to grade_prel_2\n2) Grades 3-5 to grade_3_5\n3) Grades 6-8 to grade_6_8\n4)Grades 9-12 to grade_9_12\n'

# %%
# Remove ampersands, split the strings by commas
train_data_df['project_grade_category_updated'] = train_data_df['project_grade_category'].str.split(" ")


# # # Concatenate the categories into a single string
train_data_df['project_grade_category_updated'] = train_data_df['project_grade_category_updated'].apply(lambda words: "_".join(word.strip().lower().replace("-", "_") for word in words))
train_data_df.head()
# Out:
#              id                        teacher_id teacher_prefix school_state  \
# 160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.           IN
# 140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.           FL
# 21895   p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.           AZ
# 45      p246581  f3cb9bffbba169bef1a77b243e620b60           Mrs.           KY
# 172407  p104768  be1f7507a41f8479dc06f047086a39ec           Mrs.           TX
#
#        project_submitted_datetime project_grade_category  \
# 160221        2016-12-05 13:43:57          Grades PreK-2
# 140945        2016-10-25 09:22:10             Grades 6-8
# 21895         2016-08-31 12:03:56             Grades 6-8
# 45            2016-10-06 21:16:17          Grades PreK-2
# 172407        2016-07-11 01:10:09          Grades PreK-2
#
#                  project_subject_categories     project_subject_subcategories  \
# 160221                  Literacy & Language                     ESL, Literacy
# 140945    History & Civics, Health & Sports  Civics & Government, Team Sports
# 21895                       Health & Sports    Health & Wellness, Team Sports
# 45      Literacy & Language, Math & Science             Literacy, Mathematics
# 172407                       Math & Science                       Mathematics
#
#                                             project_title  \
# 160221   Educational Support for English Learners at Home
# 140945              Wanted: Projector for Hungry Learners
# 21895   Soccer Equipment for AWESOME Middle School Stu...
# 45                                 Techie Kindergarteners
# 172407                             Interactive Math Tools
#
#                                           project_essay_1  \
# 160221  My students are English learners that are work...
# 140945  Our students arrive to our school eager to lea...
# 21895   \r\n\"True champions aren't always the ones th...
# 45      I work at a unique school filled with both ESL...
# 172407  Our second grade classroom next year will be m...
#
#                                           project_essay_2 project_essay_3  \
# 160221  \"The limits of your language are the limits o...             NaN
# 140945  The projector we need for our school is very c...             NaN
# 21895   The students on the campus come to school know...             NaN
# 45      My students live in high poverty conditions wi...             NaN
# 172407  For many students, math is a subject that does...             NaN
#
#        project_essay_4                           project_resource_summary  \
# 160221             NaN  My students need opportunities to practice beg...
# 140945             NaN  My students need a projector to help with view...
# 21895              NaN  My students need shine guards, athletic socks,...
# 45                 NaN  My students need to engage in Reading and Math...
# 172407             NaN  My students need hands on practice in mathemat...
#
#         teacher_number_of_previously_posted_projects  project_is_approved  \
# 160221                                             0                    0
# 140945                                             7                    1
# 21895                                              1                    0
# 45                                                 4                    1
# 172407                                             1                    1
#
#        project_subject_categories_updated  \
# 160221                  literacy_language
# 140945       history_civics health_sports
# 21895                       health_sports
# 45         literacy_language math_science
# 172407                       math_science
#
#        project_subject_subcategories_updated project_grade_category_updated
# 160221                          esl literacy                  grades_prek_2
# 140945         civics_government team_sports                     grades_6_8
# 21895            health_wellness team_sports                     grades_6_8
# 45                      literacy mathematics                  grades_prek_2
# 172407                           mathematics                  grades_prek_2

# %%
# checking teacher prefix value counts
train_data_df['teacher_prefix'].value_counts()
# Out:
# Mrs.       57269
# Ms.        38955
# Mr.        10648
# Teacher     2360
# Dr.           13
# Name: teacher_prefix, dtype: int64

# %%
'''
Formatting of data in the following way
Mrs. to mrs
Ms. to ms
Mr. to mr
Teacher toteacher
Dr. to dr
'''
# Out:
# '\nFormatting of data in the following way\nMrs. to mrs\nMs. to ms\nMr. to mr\nTeacher toteacher\nDr. to dr\n'

# %%
# Replacing Mrs., Ms. to mrs,ms, etc
train_data_df['teacher_prefix_upgrade'] = train_data_df['teacher_prefix'].str.replace(r"\.", "").str.lower()
train_data_df.head()
# Out:
# <ipython-input-33-696da024c110>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data_df['teacher_prefix_upgrade'] = train_data_df['teacher_prefix'].str.replace(r"\.", "").str.lower()
#              id                        teacher_id teacher_prefix school_state  \
# 160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.           IN
# 140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.           FL
# 21895   p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.           AZ
# 45      p246581  f3cb9bffbba169bef1a77b243e620b60           Mrs.           KY
# 172407  p104768  be1f7507a41f8479dc06f047086a39ec           Mrs.           TX
#
#        project_submitted_datetime project_grade_category  \
# 160221        2016-12-05 13:43:57          Grades PreK-2
# 140945        2016-10-25 09:22:10             Grades 6-8
# 21895         2016-08-31 12:03:56             Grades 6-8
# 45            2016-10-06 21:16:17          Grades PreK-2
# 172407        2016-07-11 01:10:09          Grades PreK-2
#
#                  project_subject_categories     project_subject_subcategories  \
# 160221                  Literacy & Language                     ESL, Literacy
# 140945    History & Civics, Health & Sports  Civics & Government, Team Sports
# 21895                       Health & Sports    Health & Wellness, Team Sports
# 45      Literacy & Language, Math & Science             Literacy, Mathematics
# 172407                       Math & Science                       Mathematics
#
#                                             project_title  \
# 160221   Educational Support for English Learners at Home
# 140945              Wanted: Projector for Hungry Learners
# 21895   Soccer Equipment for AWESOME Middle School Stu...
# 45                                 Techie Kindergarteners
# 172407                             Interactive Math Tools
#
#                                           project_essay_1  \
# 160221  My students are English learners that are work...
# 140945  Our students arrive to our school eager to lea...
# 21895   \r\n\"True champions aren't always the ones th...
# 45      I work at a unique school filled with both ESL...
# 172407  Our second grade classroom next year will be m...
#
#                                           project_essay_2 project_essay_3  \
# 160221  \"The limits of your language are the limits o...             NaN
# 140945  The projector we need for our school is very c...             NaN
# 21895   The students on the campus come to school know...             NaN
# 45      My students live in high poverty conditions wi...             NaN
# 172407  For many students, math is a subject that does...             NaN
#
#        project_essay_4                           project_resource_summary  \
# 160221             NaN  My students need opportunities to practice beg...
# 140945             NaN  My students need a projector to help with view...
# 21895              NaN  My students need shine guards, athletic socks,...
# 45                 NaN  My students need to engage in Reading and Math...
# 172407             NaN  My students need hands on practice in mathemat...
#
#         teacher_number_of_previously_posted_projects  project_is_approved  \
# 160221                                             0                    0
# 140945                                             7                    1
# 21895                                              1                    0
# 45                                                 4                    1
# 172407                                             1                    1
#
#        project_subject_categories_updated  \
# 160221                  literacy_language
# 140945       history_civics health_sports
# 21895                       health_sports
# 45         literacy_language math_science
# 172407                       math_science
#
#        project_subject_subcategories_updated project_grade_category_updated  \
# 160221                          esl literacy                  grades_prek_2
# 140945         civics_government team_sports                     grades_6_8
# 21895            health_wellness team_sports                     grades_6_8
# 45                      literacy mathematics                  grades_prek_2
# 172407                           mathematics                  grades_prek_2
#
#        teacher_prefix_upgrade
# 160221                    mrs
# 140945                     mr
# 21895                      ms
# 45                        mrs
# 172407                    mrs

# %%
# working school_state value counts
train_data_df['school_state'].value_counts()
# Out:
# CA    15387
# TX     7396
# NY     7318
# FL     6185
# NC     5091
# IL     4350
# GA     3963
# SC     3935
# MI     3161
# PA     3108
# IN     2620
# MO     2576
# OH     2467
# LA     2394
# MA     2389
# WA     2334
# OK     2276
# NJ     2237
# AZ     2147
# VA     2045
# WI     1827
# AL     1762
# UT     1731
# TN     1688
# CT     1663
# MD     1514
# NV     1367
# MS     1323
# KY     1304
# OR     1242
# MN     1208
# CO     1111
# AR     1049
# ID      693
# IA      666
# KS      634
# NM      557
# DC      516
# HI      507
# ME      505
# WV      503
# NH      348
# AK      345
# DE      343
# NE      309
# SD      300
# RI      285
# MT      245
# ND      143
# WY       98
# VT       80
# Name: school_state, dtype: int64

# %%
# converting to lower case
train_data_df['school_state_upgrade'] = train_data_df['school_state'].str.lower()
train_data_df.head()
# Out:
#              id                        teacher_id teacher_prefix school_state  \
# 160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.           IN
# 140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.           FL
# 21895   p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.           AZ
# 45      p246581  f3cb9bffbba169bef1a77b243e620b60           Mrs.           KY
# 172407  p104768  be1f7507a41f8479dc06f047086a39ec           Mrs.           TX
#
#        project_submitted_datetime project_grade_category  \
# 160221        2016-12-05 13:43:57          Grades PreK-2
# 140945        2016-10-25 09:22:10             Grades 6-8
# 21895         2016-08-31 12:03:56             Grades 6-8
# 45            2016-10-06 21:16:17          Grades PreK-2
# 172407        2016-07-11 01:10:09          Grades PreK-2
#
#                  project_subject_categories     project_subject_subcategories  \
# 160221                  Literacy & Language                     ESL, Literacy
# 140945    History & Civics, Health & Sports  Civics & Government, Team Sports
# 21895                       Health & Sports    Health & Wellness, Team Sports
# 45      Literacy & Language, Math & Science             Literacy, Mathematics
# 172407                       Math & Science                       Mathematics
#
#                                             project_title  \
# 160221   Educational Support for English Learners at Home
# 140945              Wanted: Projector for Hungry Learners
# 21895   Soccer Equipment for AWESOME Middle School Stu...
# 45                                 Techie Kindergarteners
# 172407                             Interactive Math Tools
#
#                                           project_essay_1  ...  \
# 160221  My students are English learners that are work...  ...
# 140945  Our students arrive to our school eager to lea...  ...
# 21895   \r\n\"True champions aren't always the ones th...  ...
# 45      I work at a unique school filled with both ESL...  ...
# 172407  Our second grade classroom next year will be m...  ...
#
#        project_essay_3 project_essay_4  \
# 160221             NaN             NaN
# 140945             NaN             NaN
# 21895              NaN             NaN
# 45                 NaN             NaN
# 172407             NaN             NaN
#
#                                  project_resource_summary  \
# 160221  My students need opportunities to practice beg...
# 140945  My students need a projector to help with view...
# 21895   My students need shine guards, athletic socks,...
# 45      My students need to engage in Reading and Math...
# 172407  My students need hands on practice in mathemat...
#
#        teacher_number_of_previously_posted_projects  project_is_approved  \
# 160221                                            0                    0
# 140945                                            7                    1
# 21895                                             1                    0
# 45                                                4                    1
# 172407                                            1                    1
#
#         project_subject_categories_updated  \
# 160221                   literacy_language
# 140945        history_civics health_sports
# 21895                        health_sports
# 45          literacy_language math_science
# 172407                        math_science
#
#        project_subject_subcategories_updated project_grade_category_updated  \
# 160221                          esl literacy                  grades_prek_2
# 140945         civics_government team_sports                     grades_6_8
# 21895            health_wellness team_sports                     grades_6_8
# 45                      literacy mathematics                  grades_prek_2
# 172407                           mathematics                  grades_prek_2
#
#        teacher_prefix_upgrade school_state_upgrade
# 160221                    mrs                   in
# 140945                     mr                   fl
# 21895                      ms                   az
# 45                        mrs                   ky
# 172407                    mrs                   tx
#
# [5 rows x 21 columns]

# %%
# Merging Eassay
# merge  column text dataframe:
train_data_df["essay"] = train_data_df["project_essay_1"].map(str) +\
                        train_data_df["project_essay_2"].map(str) + \
                        train_data_df["project_essay_3"].map(str) + \
                        train_data_df["project_essay_4"].map(str)

# %%
# Working essay column
# 1) Initial data
train_data_df[train_data_df["id"]=="p182444"]["essay"].values[0]
# Out:
# '\\r\\n\\"True champions aren\'t always the ones that win, but those with the most guts.\\" By Mia Hamm This quote best describes how the students at Cholla Middle School approach playing sports, especially for the girls and boys soccer teams. The teams are made up of 7th and 8th grade students, and most of them have not had the opportunity to play in an organized sport due to family financial difficulties. \\r\\nI teach at a Title One middle school in an urban neighborhood. 74% of our students qualify for free and reduced lunch and many come from very activity/ sport opportunity-poor homes. My students love to participate in sports to learn new skills and be apart of team atmosphere. My school lacks the funding to meet my students’ needs and I am concerned that their lack of exposure will not prepare them for the participating in sports and teams in high school. By the end of the school year, the goal is to provide our students with an opportunity to learn a variety of soccer skills, and positive qualities of a person who actively participates on a team.The students on the campus come to school knowing they face an uphill battle when it comes to participating in organized sports. The players would thrive on the field, with the confidence from having the appropriate soccer equipment to play soccer to the best of their abilities. The students will experience how to be a helpful person by being part of team that teaches them to be positive, supportive, and encouraging to others. \\r\\nMy students will be using the soccer equipment during practice and games on a daily basis to learn and practice the necessary skills to develop a strong soccer team. This experience will create the opportunity for students to learn about being part of a team, and how to be a positive contribution for their teammates. The students will get the opportunity to learn and practice a variety of soccer skills, and how to use those skills during a game.  Access to this type of experience is nearly impossible without soccer equipment for the students/ players to utilize during practice and games .nannan'

# %%
# performing action on entire dataset
train_data_df['essay_updated'] = train_data_df['essay'].str.replace(r'\\r|\\n|\\|nan',"", regex=True)
train_data_df.head()
# Out:
#              id                        teacher_id teacher_prefix school_state  \
# 160221  p253737  c90749f5d961ff158d4b4d1e7dc665fc           Mrs.           IN
# 140945  p258326  897464ce9ddc600bced1151f324dd63a            Mr.           FL
# 21895   p182444  3465aaf82da834c0582ebd0ef8040ca0            Ms.           AZ
# 45      p246581  f3cb9bffbba169bef1a77b243e620b60           Mrs.           KY
# 172407  p104768  be1f7507a41f8479dc06f047086a39ec           Mrs.           TX
#
#        project_submitted_datetime project_grade_category  \
# 160221        2016-12-05 13:43:57          Grades PreK-2
# 140945        2016-10-25 09:22:10             Grades 6-8
# 21895         2016-08-31 12:03:56             Grades 6-8
# 45            2016-10-06 21:16:17          Grades PreK-2
# 172407        2016-07-11 01:10:09          Grades PreK-2
#
#                  project_subject_categories     project_subject_subcategories  \
# 160221                  Literacy & Language                     ESL, Literacy
# 140945    History & Civics, Health & Sports  Civics & Government, Team Sports
# 21895                       Health & Sports    Health & Wellness, Team Sports
# 45      Literacy & Language, Math & Science             Literacy, Mathematics
# 172407                       Math & Science                       Mathematics
#
#                                             project_title  \
# 160221   Educational Support for English Learners at Home
# 140945              Wanted: Projector for Hungry Learners
# 21895   Soccer Equipment for AWESOME Middle School Stu...
# 45                                 Techie Kindergarteners
# 172407                             Interactive Math Tools
#
#                                           project_essay_1  ...  \
# 160221  My students are English learners that are work...  ...
# 140945  Our students arrive to our school eager to lea...  ...
# 21895   \r\n\"True champions aren't always the ones th...  ...
# 45      I work at a unique school filled with both ESL...  ...
# 172407  Our second grade classroom next year will be m...  ...
#
#                                  project_resource_summary  \
# 160221  My students need opportunities to practice beg...
# 140945  My students need a projector to help with view...
# 21895   My students need shine guards, athletic socks,...
# 45      My students need to engage in Reading and Math...
# 172407  My students need hands on practice in mathemat...
#
#        teacher_number_of_previously_posted_projects project_is_approved  \
# 160221                                            0                   0
# 140945                                            7                   1
# 21895                                             1                   0
# 45                                                4                   1
# 172407                                            1                   1
#
#        project_subject_categories_updated  \
# 160221                  literacy_language
# 140945       history_civics health_sports
# 21895                       health_sports
# 45         literacy_language math_science
# 172407                       math_science
#
#         project_subject_subcategories_updated  project_grade_category_updated  \
# 160221                           esl literacy                   grades_prek_2
# 140945          civics_government team_sports                      grades_6_8
# 21895             health_wellness team_sports                      grades_6_8
# 45                       literacy mathematics                   grades_prek_2
# 172407                            mathematics                   grades_prek_2
#
#        teacher_prefix_upgrade school_state_upgrade  \
# 160221                    mrs                   in
# 140945                     mr                   fl
# 21895                      ms                   az
# 45                        mrs                   ky
# 172407                    mrs                   tx
#
#                                                     essay  \
# 160221  My students are English learners that are work...
# 140945  Our students arrive to our school eager to lea...
# 21895   \r\n\"True champions aren't always the ones th...
# 45      I work at a unique school filled with both ESL...
# 172407  Our second grade classroom next year will be m...
#
#                                             essay_updated
# 160221  My students are English learners that are work...
# 140945  Our students arrive to our school eager to lea...
# 21895   "True champions aren't always the ones that wi...
# 45      I work at a unique school filled with both ESL...
# 172407  Our second grade classroom next year will be m...
#
# [5 rows x 23 columns]

# %%
# 1) processed Data
train_data_df[train_data_df["id"]=="p182444"]["essay_updated"].values[0]
# Out:
# '"True champions aren\'t always the ones that win, but those with the most guts." By Mia Hamm This quote best describes how the students at Cholla Middle School approach playing sports, especially for the girls and boys soccer teams. The teams are made up of 7th and 8th grade students, and most of them have not had the opportunity to play in an organized sport due to family ficial difficulties. I teach at a Title One middle school in an urban neighborhood. 74% of our students qualify for free and reduced lunch and many come from very activity/ sport opportunity-poor homes. My students love to participate in sports to learn new skills and be apart of team atmosphere. My school lacks the funding to meet my students’ needs and I am concerned that their lack of exposure will not prepare them for the participating in sports and teams in high school. By the end of the school year, the goal is to provide our students with an opportunity to learn a variety of soccer skills, and positive qualities of a person who actively participates on a team.The students on the campus come to school knowing they face an uphill battle when it comes to participating in organized sports. The players would thrive on the field, with the confidence from having the appropriate soccer equipment to play soccer to the best of their abilities. The students will experience how to be a helpful person by being part of team that teaches them to be positive, supportive, and encouraging to others. My students will be using the soccer equipment during practice and games on a daily basis to learn and practice the necessary skills to develop a strong soccer team. This experience will create the opportunity for students to learn about being part of a team, and how to be a positive contribution for their teammates. The students will get the opportunity to learn and practice a variety of soccer skills, and how to use those skills during a game.  Access to this type of experience is nearly impossible without soccer equipment for the students/ players to utilize during practice and games .'

# %%
# performing action on entire dataset
train_data_df['project_title'] = train_data_df['project_title'].str.replace(r'\\r|\\n|\\|nan',"", regex=True)

# %%
# performing action on entire dataset
train_data_df['project_resource_summary'] = train_data_df['project_resource_summary'].str.replace(r'\\r|\\n|\\|nan',"", regex=True)

# %%
# gererating main dataset
train_df=train_data_df[['id', 'teacher_prefix_upgrade', 'school_state_upgrade','project_title','project_resource_summary',
       'teacher_number_of_previously_posted_projects', 'project_is_approved',
       'project_subject_categories_updated',
       'project_subject_subcategories_updated',
       'project_grade_category_updated','essay_updated']]

train_df.head()
# Out:
#              id teacher_prefix_upgrade school_state_upgrade  \
# 160221  p253737                    mrs                   in
# 140945  p258326                     mr                   fl
# 21895   p182444                     ms                   az
# 45      p246581                    mrs                   ky
# 172407  p104768                    mrs                   tx
#
#                                             project_title  \
# 160221   Educational Support for English Learners at Home
# 140945              Wanted: Projector for Hungry Learners
# 21895   Soccer Equipment for AWESOME Middle School Stu...
# 45                                 Techie Kindergarteners
# 172407                             Interactive Math Tools
#
#                                  project_resource_summary  \
# 160221  My students need opportunities to practice beg...
# 140945  My students need a projector to help with view...
# 21895   My students need shine guards, athletic socks,...
# 45      My students need to engage in Reading and Math...
# 172407  My students need hands on practice in mathemat...
#
#         teacher_number_of_previously_posted_projects  project_is_approved  \
# 160221                                             0                    0
# 140945                                             7                    1
# 21895                                              1                    0
# 45                                                 4                    1
# 172407                                             1                    1
#
#        project_subject_categories_updated  \
# 160221                  literacy_language
# 140945       history_civics health_sports
# 21895                       health_sports
# 45         literacy_language math_science
# 172407                       math_science
#
#        project_subject_subcategories_updated project_grade_category_updated  \
# 160221                          esl literacy                  grades_prek_2
# 140945         civics_government team_sports                     grades_6_8
# 21895            health_wellness team_sports                     grades_6_8
# 45                      literacy mathematics                  grades_prek_2
# 172407                           mathematics                  grades_prek_2
#
#                                             essay_updated
# 160221  My students are English learners that are work...
# 140945  Our students arrive to our school eager to lea...
# 21895   "True champions aren't always the ones that wi...
# 45      I work at a unique school filled with both ESL...
# 172407  Our second grade classroom next year will be m...

# %%
# creating new data from resource by aggregating price and quantity feature
resource_price_data = resource_df.groupby('id').agg({'price':'sum', 'quantity':'sum'}).reset_index()
resource_price_data.head(10)
# Out:
#         id    price  quantity
# 0  p000001   459.56         7
# 1  p000002   515.89        21
# 2  p000003   298.97         4
# 3  p000004  1113.69        98
# 4  p000005   485.99         8
# 5  p000006   130.62         5
# 6  p000007   157.98         6
# 7  p000008   296.99        80
# 8  p000009   306.04        45
# 9  p000010    11.08        30

# %%
# merging train_df and resource_price_data
final_df = pd.merge(train_df, resource_price_data, on='id', how='left')
final_df.head()
# Out:
#         id teacher_prefix_upgrade school_state_upgrade  \
# 0  p253737                    mrs                   in
# 1  p258326                     mr                   fl
# 2  p182444                     ms                   az
# 3  p246581                    mrs                   ky
# 4  p104768                    mrs                   tx
#
#                                        project_title  \
# 0   Educational Support for English Learners at Home
# 1              Wanted: Projector for Hungry Learners
# 2  Soccer Equipment for AWESOME Middle School Stu...
# 3                             Techie Kindergarteners
# 4                             Interactive Math Tools
#
#                             project_resource_summary  \
# 0  My students need opportunities to practice beg...
# 1  My students need a projector to help with view...
# 2  My students need shine guards, athletic socks,...
# 3  My students need to engage in Reading and Math...
# 4  My students need hands on practice in mathemat...
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                             0                    0
# 1                                             7                    1
# 2                                             1                    0
# 3                                             4                    1
# 4                                             1                    1
#
#   project_subject_categories_updated project_subject_subcategories_updated  \
# 0                  literacy_language                          esl literacy
# 1       history_civics health_sports         civics_government team_sports
# 2                      health_sports           health_wellness team_sports
# 3     literacy_language math_science                  literacy mathematics
# 4                       math_science                           mathematics
#
#   project_grade_category_updated  \
# 0                  grades_prek_2
# 1                     grades_6_8
# 2                     grades_6_8
# 3                  grades_prek_2
# 4                  grades_prek_2
#
#                                        essay_updated   price  quantity
# 0  My students are English learners that are work...  154.60        23
# 1  Our students arrive to our school eager to lea...  299.00         1
# 2  "True champions aren't always the ones that wi...  516.85        22
# 3  I work at a unique school filled with both ESL...  232.90         4
# 4  Our second grade classroom next year will be m...   67.98         4

# %%
# checking shape of final data
final_df.shape
# Out:
# (109245, 13)

# %%
# cheking null values
final_df.isnull().sum()
# Out:
# teacher_prefix                                  0
# school_state                                    0
# project_title                                   0
# project_resource_summary                        0
# teacher_number_of_previously_posted_projects    0
# project_is_approved                             0
# project_subject_categories                      0
# project_subject_subcategories                   0
# project_grade_category                          0
# essay                                           0
# price                                           0
# quantity                                        0
# dtype: int64

# %%
preprocessed_data_df=final_df
preprocessed_data_df.rename(columns={'teacher_prefix_upgrade':"teacher_prefix", 'school_state_upgrade':"school_state",
       'project_subject_categories_updated':"project_subject_categories",
       'project_subject_subcategories_updated':"project_subject_subcategories",
       'project_grade_category_updated':"project_grade_category", 'essay_updated':"essay"},inplace=True)

# %%
# preprocessed_data_df.drop(columns=["id"],inplace=True)
preprocessed_data_df.head()
# Out:
#   teacher_prefix school_state  \
# 0            mrs           in
# 1             mr           fl
# 2             ms           az
# 3            mrs           ky
# 4            mrs           tx
#
#                                        project_title  \
# 0  students english learners working english seco...
# 1  students arrive school eager learn polite gene...
# 2  true champions nt always ones win guts mia ham...
# 3  work unique school filled esl english second l...
# 4  second grade classroom next year made around 2...
#
#                             project_resource_summary  \
# 0  My students need opportunities to practice beg...
# 1  My students need a projector to help with view...
# 2  My students need shine guards, athletic socks,...
# 3  My students need to engage in Reading and Math...
# 4  My students need hands on practice in mathemat...
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                             0                    0
# 1                                             7                    1
# 2                                             1                    0
# 3                                             4                    1
# 4                                             1                    1
#
#        project_subject_categories  project_subject_subcategories  \
# 0               literacy_language                   esl literacy
# 1    history_civics health_sports  civics_government team_sports
# 2                   health_sports    health_wellness team_sports
# 3  literacy_language math_science           literacy mathematics
# 4                    math_science                    mathematics
#
#   project_grade_category                                              essay  \
# 0          grades_prek_2  students english learners working english seco...
# 1             grades_6_8  students arrive school eager learn polite gene...
# 2             grades_6_8  true champions nt always ones win guts mia ham...
# 3          grades_prek_2  work unique school filled esl english second l...
# 4          grades_prek_2  second grade classroom next year made around 2...
#
#     price  quantity
# 0  154.60        23
# 1  299.00         1
# 2  516.85        22
# 3  232.90         4
# 4   67.98         4

# %%
# Saving the file
preprocessed_data_df.to_csv("/content/drive/MyDrive/DSML/Business Case Study/Portfolio/1.DS_Portfolio/preprocessed_data_df_updated.csv",index=False)

# %%
# checking null values
preprocessed_data_df.isnull().sum()
# Out:
# teacher_prefix                                  0
# school_state                                    0
# project_title                                   0
# project_resource_summary                        0
# teacher_number_of_previously_posted_projects    0
# project_is_approved                             0
# project_subject_categories                      0
# project_subject_subcategories                   0
# project_grade_category                          0
# essay                                           0
# price                                           0
# quantity                                        0
# dtype: int64

# %% [markdown]
# **Graphical Analysis and Hypothesis Testing**

# %% [markdown]
# Analysisng Categorical variable along with hypothesis testing

# %% [markdown]
# 1) Analysing project subject category

# %%
from scipy.stats import chi2_contingency

# %%
'''
Analyzing project subject categories
'''
# Create a contingency table for project_subject_categories
contingency_table_subject_category = pd.crosstab(preprocessed_data_df["project_subject_categories"], preprocessed_data_df["project_is_approved"],margins=True)
# contingency_table_subject_category = pd.crosstab(preprocessed_data_df["project_subject_categories"], preprocessed_data_df["project_is_approved"])

# Sort the contingency table in descending order
# contingency_table_subject_category_sorted = contingency_table_subject_category.sort_values(by=[1,0] ,ascending=False)
contingency_table_subject_category_sorted = contingency_table_subject_category.sort_values(by="All" ,ascending=False)


# Display the contingency table
contingency_table_subject_category_sorted
# Out:
# project_is_approved                       0      1     All
# project_subject_categories
# All                                   16542  92703  109245
# literacy_language                      3135  20519   23654
# math_science                           3081  13991   17072
# literacy_language math_science         1911  12723   14634
# health_sports                          1537   8640   10177
# music_the_arts                          751   4429    5180
# special_needs                           795   3431    4226
# literacy_language special_needs         572   3389    3961
# applied_learning                        699   3072    3771
# math_science literacy_language          321   1968    2289
# applied_learning literacy_language      304   1887    2191
# history_civics                          306   1545    1851
# math_science special_needs              309   1531    1840
# literacy_language music_the_arts        282   1475    1757
# math_science music_the_arts             276   1366    1642
# applied_learning special_needs          272   1195    1467
# history_civics literacy_language        150   1271    1421
# health_sports special_needs             176   1215    1391
# warmth care_hunger                       97   1212    1309
# math_science applied_learning           201   1019    1220
# applied_learning math_science           197    855    1052
# literacy_language history_civics         99    710     809
# health_sports literacy_language         124    679     803
# applied_learning music_the_arts         146    612     758
# math_science history_civics              94    558     652
# literacy_language applied_learning       92    544     636
# applied_learning health_sports          107    501     608
# math_science health_sports               88    326     414
# history_civics math_science              46    276     322
# history_civics music_the_arts            52    260     312
# special_needs music_the_arts             50    252     302
# health_sports math_science               48    223     271
# history_civics special_needs             47    205     252
# health_sports applied_learning           29    163     192
# applied_learning history_civics          32    146     178
# health_sports music_the_arts             30    125     155
# music_the_arts special_needs             17    121     138
# literacy_language health_sports          14     58      72
# health_sports history_civics              5     38      43
# special_needs health_sports               9     33      42
# history_civics applied_learning           9     33      42
# special_needs warmth care_hunger          5     18      23
# health_sports warmth care_hunger          1     22      23
# music_the_arts health_sports              6     13      19
# music_the_arts history_civics             5     13      18
# history_civics health_sports              1     12      13
# math_science warmth care_hunger           5      6      11
# music_the_arts applied_learning           3      7      10
# applied_learning warmth care_hunger       2      8      10
# literacy_language warmth care_hunger      2      7       9
# music_the_arts warmth care_hunger         1      1       2
# history_civics warmth care_hunger         1      0       1

# %%
contingency_table_subject_category.columns
# Out:
# Index([0, 1, 'All'], dtype='object', name='project_is_approved')

# %%
# # Create a contingency table for project_subject_categories
# contingency_table = pd.crosstab(preprocessed_data_df["project_subject_categories"], preprocessed_data_df["project_is_approved"])
# contingency_table
# Select top 10 values
# top_10_values = contingency_table_subject_category.nlargest(40, columns=True,keep='first')
# top_10_values = contingency_table_subject_category.nlargest(10, columns=[1,0])
top_10_values = contingency_table_subject_category.nlargest(10, columns=True)


# dropping 'All'
top_10_values.drop(index="All",inplace=True)

# Reverse the order to show top values first
top_10_values = top_10_values.iloc[::-1]
# print(top_10_values)

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 10))  # Width, height in inches

# Create a bar plot with stacked bars
barplot = top_10_values.plot(kind='barh', stacked=True, rot=0, ax=ax)

# Show the plot
plt.show()

# %%
'''
As per the analysis literacy_language, math_science,literacy_language math_science, health_sports have high volume
'''
# Out:
# '\nAs per the analysis literacy_language, math_science,literacy_language math_science, health_sports have high volume\n'

# %%
# Select top 10 categories
top_10_categories = contingency_table_subject_category.nlargest(10, columns=True).index
print(top_10_categories)

# Filter contingency table for top 10 categories
contingency_table_top_10 = contingency_table_subject_category.loc[top_10_categories]

# Set the figure size
plt.figure(figsize=(8,8))

# Create the heatmap with annotations
sns.heatmap(contingency_table_top_10, cmap="YlGnBu",
            annot=True, cbar=False, fmt='d')

# Show the plot
plt.show()
# Out:
# Index(['All', 'literacy_language', 'math_science',
#        'literacy_language math_science', 'health_sports', 'music_the_arts',
#        'special_needs', 'literacy_language special_needs', 'applied_learning',
#        'math_science literacy_language'],
#       dtype='object', name='project_subject_categories')

# %%
'''
As per the analysis literacy_language, math_science,literacy_language math_science, health_sports are highly correlated for the approved project
'''
# Out:
# '\nAs per the analysis literacy_language, math_science,literacy_language math_science, health_sports are highly correlated for the approved project\n'

# %%
# Hypothesis testing
'''
Null hypothesis (H0): There is no association between the category column(project_subject_categories) and the target variable(project_is_approved).
Alternative hypothesis (HA): There is an association between the category column(project_subject_categories) and the target variable(project_is_approved).
'''
# Out:
# '\nNull hypothesis (H0): There is no association between the category column(project_subject_categories) and the target variable(project_is_approved).\nAlternative hypothesis (HA): There is an association between the category column(project_subject_categories) and the target variable(project_is_approved).\n'

# %%
# Perform chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_table_subject_category)

# Print the results
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Degrees of freedom:", dof)
print("Expected frequencies:")
# print(pd.DataFrame(expected, index=contingency_table.index, columns=contingency_table.columns))
# Out:
# Chi-square statistic: 512.334094894877
# P-value: 6.094703367676953e-56
# Degrees of freedom: 102
# Expected frequencies:

# %%
from scipy.stats import chi2
cr=chi2.ppf(q=0.95,df=dof)
print("Critical Region= ",cr)
alpha=1-0.95
print("aplha= ",alpha)
# Out:
# Critical Region=  126.57414819149433
# aplha=  0.050000000000000044

# %%
'''
As p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.
As per the project_subject_categoriesr is dependent on project approved or not
'''
# Out:
# '\nAs p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.\nAs per the project_subject_categoriesr is dependent on project approved or not\n'

# %% [markdown]
# 2) Analysis of project subject_subcategory

# %%
'''
Analyzing project_subject_subcategories
'''
# Create a contingency table for project_subject_categories
contingency_table_project_subject_subcategories = pd.crosstab(preprocessed_data_df["project_subject_subcategories"], preprocessed_data_df["project_is_approved"],margins=True)
# Sort the contingency table in descending order
contingency_table_project_subject_subcategories_sorted = contingency_table_project_subject_subcategories.sort_values(by="All", ascending=False)

# Display the contingency table
contingency_table_project_subject_subcategories_sorted.head(10)
# Out:
# project_is_approved                 0      1     All
# project_subject_subcategories
# All                             16542  92703  109245
# literacy                         1115   8371    9486
# literacy mathematics             1065   7259    8324
# literature_writing mathematics    783   5139    5922
# literacy literature_writing       748   4823    5571
# mathematics                       994   4385    5379
# literature_writing                655   3845    4500
# special_needs                     795   3431    4226
# health_wellness                   452   3131    3583
# applied_sciences mathematics      575   2824    3399

# %%
preprocessed_data_df.columns
# Out:
# Index(['teacher_prefix', 'school_state', 'project_title',
#        'project_resource_summary',
#        'teacher_number_of_previously_posted_projects', 'project_is_approved',
#        'project_subject_categories', 'project_subject_subcategories',
#        'project_grade_category', 'essay', 'price', 'quantity'],
#       dtype='object')

# %%
# Select top 10 values
top_10_values = contingency_table_project_subject_subcategories.nlargest(10, columns=True,keep='first')
# dropping 'All'
top_10_values.drop(index="All",inplace=True)

# Reverse the order to show top values first
top_10_values = top_10_values.iloc[::-1]

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 10))  # Width, height in inches

# Create a bar plot with stacked bars
barplot = top_10_values.plot(kind='barh', stacked=True, rot=0, ax=ax)

# Show the plot
plt.show()

# %%
'''
As per the analysis literacy,literacy mathematics	,literature_writing mathematics	,literacy literature_writing,
mathematics	,literature_writing, special_needs has high volumne of data
'''
# Out:
# '\nAs per the analysis literacy,literacy mathematics\t,literature_writing mathematics\t,literacy literature_writing,\nmathematics\t,literature_writing, special_needs has high volumne of data\n'

# %%
# Select top 10 categories
top_10_categories = contingency_table_project_subject_subcategories.nlargest(10, columns=True).index

# Filter contingency table for top 10 categories
contingency_table_top_10 = contingency_table_project_subject_subcategories.loc[top_10_categories]

# Set the figure size
plt.figure(figsize=(8,8))

# Create the heatmap with annotations
sns.heatmap(contingency_table_top_10, cmap="YlGnBu",
            annot=True, cbar=False, fmt='d')

# Show the plot
plt.show()

# %%
'''
As per the analysis literacy,literacy mathematics	,literature_writing mathematics	,literacy literature_writing,
mathematics	,literature_writing, special_needs has high volumne of data
'''
# Out:
# '\nAs per the analysis literacy,literacy mathematics\t,literature_writing mathematics\t,literacy literature_writing,\nmathematics\t,literature_writing, special_needs has high volumne of data\n'

# %%
# Hypothesis testing
'''
Null hypothesis (H0): There is no association between the category column(project_subject_categories) and the target variable(project_is_approved).
Alternative hypothesis (HA): There is an association between the category column(project_subject_categories) and the target variable(project_is_approved).
'''
# Out:
# '\nNull hypothesis (H0): There is no association between the category column(project_subject_categories) and the target variable(project_is_approved).\nAlternative hypothesis (HA): There is an association between the category column(project_subject_categories) and the target variable(project_is_approved).\n'

# %%
# Perform chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_table_project_subject_subcategories)

# Print the results
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Degrees of freedom:", dof)
print("Expected frequencies:")
# print(pd.DataFrame(expected, index=contingency_table.index, columns=contingency_table.columns))
# Out:
# Chi-square statistic: 1131.4771626054871
# P-value: 1.1746553274628082e-13
# Degrees of freedom: 802
# Expected frequencies:

# %%
from scipy.stats import chi2
cr=chi2.ppf(q=0.95,df=dof)
print("Critical Region= ",cr)
alpha=1-0.95
print("aplha= ",alpha)
# Out:
# Critical Region=  868.9936183053817
# aplha=  0.050000000000000044

# %%
'''
As p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.
As per the project_subject_categoriesr is dependent on project approved or not
'''
# Out:
# '\nAs p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.\nAs per the project_subject_categoriesr is dependent on project approved or not\n'

# %% [markdown]
# 3) Analysing teacher prefix data

# %%
'''
Analyzing teacher prefix
'''
# Create a contingency table for project_subject_categories
contingency_teacher_prefix = pd.crosstab(preprocessed_data_df["teacher_prefix"], preprocessed_data_df["project_is_approved"],margins=True)
# Sort the contingency table in descending order
contingency_teacher_prefix_sorted = contingency_teacher_prefix.sort_values(by="All", ascending=False)

# Display the contingency table
contingency_teacher_prefix_sorted
# Out:
# project_is_approved      0      1     All
# teacher_prefix
# All                  16542  92703  109245
# mrs                   8272  48997   57269
# ms                    6095  32860   38955
# mr                    1688   8960   10648
# teacher                483   1877    2360
# dr                       4      9      13

# %%
# Select top 10 values
top_10_values = contingency_teacher_prefix.nlargest(10, columns=True,keep='first')
# dropping 'All'
top_10_values.drop(index="All",inplace=True)

# Reverse the order to show top values first
top_10_values = top_10_values.iloc[::-1]

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 10))  # Width, height in inches

# Create a bar plot with stacked bars
barplot = top_10_values.plot(kind='barh', stacked=True, rot=0, ax=ax)

# Show the plot
plt.show()

# %%
'''
As per the analysis ms, mrs have high volume
'''
# Out:
# '\nAs per the analysis ms, mrs have high volume\n'

# %%
# Select top 10 categories
top_10_categories = contingency_teacher_prefix.nlargest(10, columns=True).index

# Filter contingency table for top 10 categories
contingency_table_top_10 = contingency_teacher_prefix.loc[top_10_categories]

# Set the figure size
plt.figure(figsize=(8,8))

# Create the heatmap with annotations
sns.heatmap(contingency_table_top_10, cmap="YlGnBu",
            annot=True, cbar=False, fmt='d')

# Show the plot
plt.show()

# %%
'''
As per the analysis ms, mrs have high corelation on approved project
'''
# Out:
# '\nAs per the analysis ms, mrs have high corelation on approved project\n'

# %%
# hypothesis testin
'''
Null hypothesis (H0): There is no association between the category column(teacher_prefix) and the target variable(project_is_approved).
Alternative hypothesis (HA): There is an association between the category column(teacher_prefix) and the target variable(project_is_approved).
'''
# Out:
# '\nNull hypothesis (H0): There is no association between the category column(teacher_prefix) and the target variable(project_is_approved).\nAlternative hypothesis (HA): There is an association between the category column(teacher_prefix) and the target variable(project_is_approved).\n'

# %%
# Perform chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_teacher_prefix)

# Print the results
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Degrees of freedom:", dof)
print("Expected frequencies:")
# print(pd.DataFrame(expected, index=contingency_table.index, columns=contingency_table.columns))
# Out:
# Chi-square statistic: 88.13584951486911
# P-value: 1.2534940223797192e-14
# Degrees of freedom: 10
# Expected frequencies:

# %%
from scipy.stats import chi2
cr=chi2.ppf(q=0.95,df=dof)
print("Critical Region= ",cr)
alpha=1-0.95
print("aplha= ",alpha)
# Out:
# Critical Region=  18.307038053275146
# aplha=  0.050000000000000044

# %%
'''
As p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.
As per the teacher_prefix is dependent on project approved or not
'''
# Out:
# '\nAs p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.\nAs per the teacher_prefix is dependent on project approved or not\n'

# %% [markdown]
# 4) Analysing school state

# %%
'''
Analyzing school_state
'''
# Create a contingency table for project_subject_categories
contingency_school_state_category = pd.crosstab(preprocessed_data_df["school_state"], preprocessed_data_df["project_is_approved"],margins=True)
# Sort the contingency table in descending order
contingency_school_state_category_sorted = contingency_school_state_category.sort_values(by="All", ascending=False)

# Display the contingency table
contingency_school_state_category_sorted
# Out:
# project_is_approved      0      1     All
# school_state
# All                  16542  92703  109245
# ca                    2183  13204   15387
# tx                    1382   6014    7396
# ny                    1027   6291    7318
# fl                    1041   5144    6185
# nc                     738   4353    5091
# il                     640   3710    4350
# ga                     634   3329    3963
# sc                     551   3384    3935
# mi                     489   2672    3161
# pa                     451   2657    3108
# in                     406   2214    2620
# mo                     374   2202    2576
# oh                     308   2159    2467
# la                     404   1990    2394
# ma                     334   2055    2389
# wa                     289   2045    2334
# ok                     376   1900    2276
# nj                     349   1888    2237
# az                     347   1800    2147
# va                     306   1739    2045
# wi                     282   1545    1827
# al                     256   1506    1762
# ut                     283   1448    1731
# tn                     253   1435    1688
# ct                     218   1445    1663
# md                     244   1270    1514
# nv                     200   1167    1367
# ms                     205   1118    1323
# ky                     178   1126    1304
# or                     186   1056    1242
# mn                     172   1036    1208
# co                     176    935    1111
# ar                     177    872    1049
# id                     114    579     693
# ia                      98    568     666
# ks                     102    532     634
# nm                      78    479     557
# dc                     102    414     516
# hi                      73    434     507
# me                      77    428     505
# wv                      73    430     503
# nh                      44    304     348
# ak                      55    290     345
# de                      35    308     343
# ne                      49    260     309
# sd                      48    252     300
# ri                      42    243     285
# mt                      45    200     245
# nd                      16    127     143
# wy                      16     82      98
# vt                      16     64      80

# %%
# Select top 10 values
top_10_values = contingency_school_state_category.nlargest(10, columns=True,keep='first')
# dropping 'All'
top_10_values.drop(index="All",inplace=True)

# Reverse the order to show top values first
top_10_values = top_10_values.iloc[::-1]

# Set the figure size
fig, ax = plt.subplots(figsize=(10, 10))  # Width, height in inches

# Create a bar plot with stacked bars
barplot = top_10_values.plot(kind='barh', stacked=True, rot=0, ax=ax)

# Show the plot
plt.show()

# %%
'''
As per the analysis ca, ny, tx,fl have high volume
'''
# Out:
# '\nAs per the analysis ca, ny, tx,fl have high volume\n'

# %%
# Select top 10 categories
top_10_categories = contingency_school_state_category.nlargest(10, columns=True).index

# Filter contingency table for top 10 categories
contingency_table_top_10 = contingency_school_state_category.loc[top_10_categories]

# Set the figure size
plt.figure(figsize=(8,8))

# Create the heatmap with annotations
sns.heatmap(contingency_table_top_10, cmap="YlGnBu",
            annot=True, cbar=False, fmt='d')

# Show the plot
plt.show()

# %%
'''
As per the analysis ca and ny have high corelation on approved project
'''
# Out:
# '\nAs per the analysis ca and ny have high corelation on approved project\n'

# %%
# hypothesis testing
'''
Null hypothesis (H0): There is no association between the category column(school_state) and the target variable(project_is_approved).
Alternative hypothesis (HA): There is an association between the category column(school_state) and the target variable(project_is_approved).
'''
# Out:
# '\nNull hypothesis (H0): There is no association between the category column(school_state) and the target variable(project_is_approved).\nAlternative hypothesis (HA): There is an association between the category column(school_state) and the target variable(project_is_approved).\n'

# %%
# Perform chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_school_state_category)

# Print the results
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Degrees of freedom:", dof)
print("Expected frequencies:")
# print(pd.DataFrame(expected, index=contingency_table.index, columns=contingency_table.columns))
# Out:
# Chi-square statistic: 196.1400210408205
# P-value: 6.360778981264269e-08
# Degrees of freedom: 102
# Expected frequencies:

# %%
from scipy.stats import chi2
cr=chi2.ppf(q=0.95,df=dof)
print("Critical Region= ",cr)
alpha=1-0.95
print("aplha= ",alpha)
# Out:
# Critical Region=  126.57414819149433
# aplha=  0.050000000000000044

# %%
'''
As p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.
As per the school_state is dependent on project approved or not
'''
# Out:
# '\nAs p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.\nAs per the school_state is dependent on project approved or not\n'

# %% [markdown]
# 5) Analysing project_grade_category

# %%
'''
Analyzing project_grade_category
'''
# Create a contingency table for project_subject_categories
contingency_project_grade_category = pd.crosstab(preprocessed_data_df["project_grade_category"], preprocessed_data_df["project_is_approved"],margins=True)
# Sort the contingency table in descending order
contingency_table_subject_category_sorted = contingency_project_grade_category.sort_values(by="All", ascending=False)

# Display the contingency table
contingency_table_subject_category_sorted
# Out:
# project_is_approved         0      1     All
# project_grade_category
# All                     16542  92703  109245
# grades_prek_2            6689  37536   44225
# grades_3_5               5408  31727   37135
# grades_6_8               2665  14258   16923
# grades_9_12              1780   9182   10962

# %%
# Select top 10 values
top_10_values = contingency_project_grade_category.nlargest(10, columns=True,keep='first')
# dropping 'All'
top_10_values.drop(index="All",inplace=True)

# Reverse the order to show top values first
top_10_values = top_10_values.iloc[::-1]

# Set the figure size
fig, ax = plt.subplots(figsize=(8,8))  # Width, height in inches

# Create a bar plot with stacked bars
barplot = top_10_values.plot(kind='barh', stacked=True, rot=0, ax=ax)

# Show the plot
plt.show()

# %%
'''
As per the analysis grade_prek_2 and grades_3_5 have high volume
'''
# Out:
# '\nAs per the analysis grade_prek_2 and grades_3_5 have high volume\n'

# %%
# Select top 10 categories
top_10_categories = contingency_project_grade_category.nlargest(10, columns=True).index

# Filter contingency table for top 10 categories
contingency_table_top_10 = contingency_project_grade_category.loc[top_10_categories]

# Set the figure size
plt.figure(figsize=(8,8))

# Create the heatmap with annotations
sns.heatmap(contingency_table_top_10, cmap="YlGnBu",
            annot=True, cbar=False, fmt='d')

# Show the plot
plt.show()

# %%
'''
As per the analysis grade_prek_2 and grades_3_5 have highly corelated to approved project
'''
# Out:
# '\nAs per the analysis grade_prek_2 and grades_3_5 have highly corelated to approved project\n'

# %%
# hypothesis testing
'''
Null hypothesis (H0): There is no association between the category column(project_grade_category) and the target variable(project_is_approved).
Alternative hypothesis (HA): There is an association between the category column(project_grade_category) and the target variable(project_is_approved).
'''
# Out:
# '\nNull hypothesis (H0): There is no association between the category column(project_grade_category) and the target variable(project_is_approved).\nAlternative hypothesis (HA): There is an association between the category column(project_grade_category) and the target variable(project_is_approved).\n'

# %%
# Perform chi-square test
chi2, p_value, dof, expected = chi2_contingency(contingency_project_grade_category)

# Print the results
print("Chi-square statistic:", chi2)
print("P-value:", p_value)
print("Degrees of freedom:", dof)
print("Expected frequencies:")
# print(pd.DataFrame(expected, index=contingency_table.index, columns=contingency_table.columns))
# Out:
# Chi-square statistic: 24.77558750658151
# P-value: 0.0016966421274175806
# Degrees of freedom: 8
# Expected frequencies:

# %%
from scipy.stats import chi2
cr=chi2.ppf(q=0.95,df=dof)
print("Critical Region= ",cr)
alpha=1-0.95
print("aplha= ",alpha)
# Out:
# Critical Region=  15.50731305586545
# aplha=  0.050000000000000044

# %%
'''
As p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.
As per the project_grade_category is dependent on project approved or not
'''
# Out:
# '\nAs p_value is less than alpha, also chi-square is falls after the critical region, hence reject the null hypothesis.\nAs per the project_grade_category is dependent on project approved or not\n'

# %%
preprocessed_data_df.columns
# Out:
# Index(['teacher_prefix', 'school_state', 'project_title',
#        'project_resource_summary',
#        'teacher_number_of_previously_posted_projects', 'project_is_approved',
#        'project_subject_categories', 'project_subject_subcategories',
#        'project_grade_category', 'essay', 'price', 'quantity'],
#       dtype='object')

# %%
# Countplot for the project_is_approved
plt.figure(figsize = (10,8))
sns.countplot(data=preprocessed_data_df,
          y='project_is_approved')
# Out:
# <Axes: xlabel='count', ylabel='project_is_approved'>

# %%
# Checking value counts
preprocessed_data_df["project_is_approved"].value_counts()
# Out:
# 1    92703
# 0    16542
# Name: project_is_approved, dtype: int64

# %%
'''
As per the analysisratio of 1 and 0 is almost 80:20
'''

# %% [markdown]
# Analysisng Numerical variable along with hypothesis testing

# %% [markdown]
# A) Boxplot Analysis and KDE plot analysis of quantity

# %%
df_box = preprocessed_data_df[preprocessed_data_df['project_is_approved'].isin([0, 1])]
plt.figure(figsize=(15, 8))
sns.boxplot(x="project_is_approved", y="quantity", data=df_box)
plt.xticks(ticks=[0, 1], labels=["0", "1"])
plt.show()

# %%
'''
As per the analysis, there are outliers in both 0's and 1's  from quantity feature
'''

# %%
print("ananlysing data based on 10percentile increase volume")
price_ = preprocessed_data_df['quantity'].values
for i in range(0, 101, 10):
  print(i, np.percentile(price_, i))
print()
print("analysing quantity from 80 to 90 percentile")
for i in range(80, 90):
  print(i, np.percentile(price_, i))
print()
print("analysing quantity from 90 to 100 percentile")
for i in range(90, 100):
  print(i, np.percentile(price_, i))

print()
print("analysing quantity from 90.1 to 100 percentile")
for i in [99.1, 99.2, 99.3, 99.4, 99.5, 99.6, 99.7, 99.8, 99.9, 100]:
  print(i, np.percentile(price_, i))
# Out:
# ananlysing data based on 10percentile increase volume
# 0 1.0
# 10 2.0
# 20 3.0
# 30 4.0
# 40 6.0
# 50 9.0
# 60 12.0
# 70 17.0
# 80 25.0
# 90 39.0
# 100 930.0
#
# analysing quantity from 80 to 90 percentile
# 80 25.0
# 81 26.0
# 82 27.0
# 83 29.0
# 84 30.0
# 85 30.0
# 86 32.0
# 87 33.0
# 88 35.0
# 89 37.0
#
# analysing quantity from 90 to 100 percentile
# 90 39.0
# 91 42.0
# 92 45.0
# 93 49.0
# 94 52.0
# 95 58.0
# 96 64.0
# 97 74.0
# 98 90.0
# 99 120.0
#
# analysing quantity from 90.1 to 100 percentile
# 99.1 125.0
# 99.2 132.0
# 99.3 140.29200000000128
# 99.4 150.0
# 99.5 159.0
# 99.6 175.0
# 99.7 192.0
# 99.8 216.0
# 99.9 264.0
# 100 930.0

# %%
# Calculate percentiles
percentiles = np.arange(1, 101)
values = np.percentile(preprocessed_data_df['quantity'], percentiles)

# Plotting using Seaborn
sns.lineplot(x=percentiles, y=values)
plt.ylabel('Value')
plt.title('Percentile Plot')
plt.grid(True)
plt.show()

# %%
'''
As per the analysis there are outliers at the extreme points i.e. from 99.1 to 100
so need to remove it
'''

# %%
# Hypothesis testing
'''
The objective of the t-test in this context is to determine if there is a statistically significant difference between the means of the numerical data(quantity) for two binary target classes.
Null hypothesis H0: no difference between the group means.
Alternate hypothesis H1: difference between the group means.
Considering the following parameters
Confidence leve= 95%
aplha=0.05
'''
# Import library
import scipy.stats as stats
t_value,p_value=stats.ttest_ind(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==1]["quantity"].values,preprocessed_data_df[preprocessed_data_df["project_is_approved"]==0]["quantity"].values)
print("t_value =",t_value)
print("p_value =",p_value)
print("alpha_value= ",0.05)
# Out:
# t_value = -17.21683726652472
# p_value = 2.4300555287575137e-66
# alpha_value=  0.05

# %%
'''
As p_values is greater than alpha (p_value<alpha) we  reject the null hypothesis.
Hence as per the hypothesis testing, quantity group for both approved and not approved project  is not equal
'''

# %%
# Overlap graph for the quantity data
plt.figure(figsize = (8,10))
sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==1]["quantity"].values,shade=True,color="r")
sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==0]["quantity"].values,shade=True,color="b")
# Out:
# <ipython-input-128-2c05e680c16f>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==1]["quantity"].values,shade=True,color="r")
# <ipython-input-128-2c05e680c16f>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==0]["quantity"].values,shade=True,color="b")
# <Axes: ylabel='Density'>

# %%
'''
As per the analysis there is slight difference between 1 and 0 and it is barely noticable. Also the
spreading of both the groups are almost same
'''

# %% [markdown]
# B) Boxplot Analysis and KDE plot analysis of teacher_number_of_previously_posted_projects data

# %%
df_box = preprocessed_data_df[preprocessed_data_df['project_is_approved'].isin([0, 1])]
plt.figure(figsize=(15, 8))
sns.boxplot(x="project_is_approved", y="teacher_number_of_previously_posted_projects", data=df_box)
plt.xticks(ticks=[0, 1], labels=["0", "1"])
plt.show()

# %%
'''
As per the analysis, there are outliers in both 0's and 1's  from quantity feature
'''

# %%
print("ananlysing data based on 10percentile increase volume")
price_ = preprocessed_data_df['teacher_number_of_previously_posted_projects'].values
for i in range(0, 101, 10):
  print(i, np.percentile(price_, i))
print()
print("analysing teacher_number_of_previously_posted_projects from 80 to 90 percentile")
for i in range(80, 90):
  print(i, np.percentile(price_, i))
print()
print("analysing teacher_number_of_previously_posted_projects from 90 to 100 percentile")
for i in range(90, 100):
  print(i, np.percentile(price_, i))

print()
print("analysing teacher_number_of_previously_posted_projects from 90.1 to 100 percentile")
for i in [99.1, 99.2, 99.3, 99.4, 99.5, 99.6, 99.7, 99.8, 99.9, 100]:
  print(i, np.percentile(price_, i))
# Out:
# ananlysing data based on 10percentile increase volume
# 0 0.0
# 10 0.0
# 20 0.0
# 30 1.0
# 40 1.0
# 50 2.0
# 60 4.0
# 70 7.0
# 80 12.0
# 90 28.0
# 100 451.0
#
# analysing teacher_number_of_previously_posted_projects from 80 to 90 percentile
# 80 12.0
# 81 13.0
# 82 14.0
# 83 15.0
# 84 17.0
# 85 18.0
# 86 19.0
# 87 21.0
# 88 23.0
# 89 25.0
#
# analysing teacher_number_of_previously_posted_projects from 90 to 100 percentile
# 90 28.0
# 91 31.0
# 92 35.0
# 93 39.0
# 94 45.0
# 95 53.0
# 96 62.0
# 97 77.0
# 98 100.0
# 99 139.0
#
# analysing teacher_number_of_previously_posted_projects from 90.1 to 100 percentile
# 99.1 145.0
# 99.2 153.0
# 99.3 162.0
# 99.4 175.0
# 99.5 186.0
# 99.6 196.0
# 99.7 214.0
# 99.8 260.51200000000244
# 99.9 313.7560000000085
# 100 451.0

# %%
# Calculate percentiles
percentiles = np.arange(1, 101)
values = np.percentile(preprocessed_data_df['teacher_number_of_previously_posted_projects'], percentiles)

# Plotting using Seaborn
sns.lineplot(x=percentiles, y=values)
plt.ylabel('Value')
plt.title('Percentile Plot')
plt.grid(True)
plt.show()

# %%
'''
As per the analysis there are outliers at the extreme points i.e. from 98 to 100
so need to remove it
'''

# %%
'''
The objective of the t-test in this context is to determine if there is a statistically significant difference between the means of the numerical data(teacher_number_of_previously_posted_projects) for two binary target classes.
Null hypothesis H0: no difference between the group means.
Alternate hypothesis H1: difference between the group means.
Considering the following parameters
Confidence leve= 95%
aplha=0.05
'''
# Import library
import scipy.stats as stats
t_value,p_value=stats.ttest_ind(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==1]["teacher_number_of_previously_posted_projects"].values,preprocessed_data_df[preprocessed_data_df["project_is_approved"]==0]["teacher_number_of_previously_posted_projects"].values)
print("t_value =",t_value)
print("p_value =",p_value)
print("aplha value= ",0.05)
# Out:
# t_value = 21.482313390796964
# p_value = 3.712587414386554e-102
# aplha value=  0.05

# %%
'''
As p_values is greater than alpha (p_value<alpha) we  reject the null hypothesis.
Hence as per the hypothesis testing, teacher_number_of_previously_posted_projects group for both approved and not approved project  is not equal
'''

# %%
# Overlap graph for the teacher_number_of_previously_posted_projects data
plt.figure(figsize = (8,10))
sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==1]["teacher_number_of_previously_posted_projects"].values,shade=True,color="r")
sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==0]["teacher_number_of_previously_posted_projects"].values,shade=True,color="b")
# Out:
# <ipython-input-135-36282965e9db>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==1]["teacher_number_of_previously_posted_projects"].values,shade=True,color="r")
# <ipython-input-135-36282965e9db>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==0]["teacher_number_of_previously_posted_projects"].values,shade=True,color="b")
# <Axes: ylabel='Density'>

# %%
'''
As per the analysis there is slight difference between 1 and 0 and it is barely noticable. Also the
spreading of both the groups are almost same
'''

# %% [markdown]
# C) Boxplot Analysis and KDE plot analysis of price

# %%
df_box = preprocessed_data_df[preprocessed_data_df['project_is_approved'].isin([0, 1])]
plt.figure(figsize=(15, 8))
sns.boxplot(x="project_is_approved", y="price", data=df_box)
plt.xticks(ticks=[0, 1], labels=["0", "1"])
plt.show()

# %%
'''
As per the analysis, there are outliers in both 0's and 1's  from quantity feature
'''

# %%
print("ananlysing data based on 10percentile increase volume")
price_ = preprocessed_data_df['price'].values
for i in range(0, 101, 10):
  print(i, np.percentile(price_, i))
print()
print("analysing price from 80 to 90 percentile")
for i in range(80, 90):
  print(i, np.percentile(price_, i))
print()
print("analysing price from 90 to 100 percentile")
for i in range(90, 100):
  print(i, np.percentile(price_, i))

print()
# print()
print("analysing quantity from 90.1 to 100 percentile")
for i in [99.1, 99.2, 99.3, 99.4, 99.5, 99.6, 99.7, 99.8, 99.9, 100]:
  print(i, np.percentile(price_, i))
# Out:
# ananlysing data based on 10percentile increase volume
# 0 0.66
# 10 38.94400000000002
# 20 83.9
# 30 123.02199999999996
# 40 163.78
# 50 206.22
# 60 266.89
# 70 334.96000000000004
# 80 428.48
# 90 619.4340000000002
# 100 9999.0
#
# analysing price from 80 to 90 percentile
# 80 428.48
# 81 441.71999999999997
# 82 454.9508000000001
# 83 469.99
# 84 479.53879999999975
# 85 499.0
# 86 514.8951999999999
# 87 538.6307999999999
# 88 563.19
# 89 590.77
#
# analysing price from 90 to 100 percentile
# 90 619.4340000000002
# 91 651.2
# 92 691.8348000000001
# 93 729.96
# 94 776.8235999999999
# 95 839.98
# 96 938.88
# 97 1057.4623999999953
# 98 1260.1355999999982
# 99 1583.4799999999977
#
# analysing quantity from 90.1 to 100 percentile
# 99.1 1626.149040000001
# 99.2 1690.998639999999
# 99.3 1763.4580800000024
# 99.4 1827.8365600000127
# 99.5 1915.99
# 99.6 1999.99
# 99.7 2269.788279999967
# 99.8 2895.365120000003
# 99.9 3999.0
# 100 9999.0

# %%
# Calculate percentiles
percentiles = np.arange(1, 101)
values = np.percentile(preprocessed_data_df['price'], percentiles)

# Plotting using Seaborn
sns.lineplot(x=percentiles, y=values)
plt.ylabel('Value')
plt.title('Percentile Plot')
plt.grid(True)
plt.show()

# %%
'''
As per the analysis there are outliers at the extreme points i.e. from 97 to 100
so need to remove it
'''

# %%
'''
The objective of the t-test in this context is to determine if there is a statistically significant difference between the means of the numerical data(price) for two binary target classes.
Null hypothesis H0: no difference between the group means.
Alternate hypothesis H1: difference between the group means.
Considering the following parameters
Confidence leve= 95%
aplha=0.05
'''
# Import library
import scipy.stats as stats
t_value,p_value=stats.ttest_ind(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==1]["price"].values,preprocessed_data_df[preprocessed_data_df["project_is_approved"]==0]["price"].values)
print("t_value =",t_value)
print("p_value =",p_value)
print("aplha value= ",0.05)
# Out:
# t_value = -23.55107138283895
# p_value = 2.4752087405504007e-122
# aplha value=  0.05

# %%
'''
As p_values is greater than alpha (p_value<alpha) we  reject the null hypothesis.
Hence as per the hypothesis testing, price group for both approved and not approved roject  is not equal
'''

# %%
# Overlap graph for the price data
plt.figure(figsize = (8,10))
sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==1]["price"].values,shade=True,color="r")
sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==0]["price"].values,shade=True,color="b")
# Out:
# <ipython-input-141-e64930ba43fc>:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==1]["price"].values,shade=True,color="r")
# <ipython-input-141-e64930ba43fc>:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(preprocessed_data_df[preprocessed_data_df["project_is_approved"]==0]["price"].values,shade=True,color="b")
# <Axes: ylabel='Density'>

# %%
'''
As per the analysis there is slight difference between 1 and 0 and it is barely noticable. Also the
spreading of both the groups are almost same
'''

# %%
preprocessed_data_df.columns
# Out:
# Index(['teacher_prefix', 'school_state', 'project_title',
#        'project_resource_summary',
#        'teacher_number_of_previously_posted_projects', 'project_is_approved',
#        'project_subject_categories', 'project_subject_subcategories',
#        'project_grade_category', 'essay', 'price', 'quantity'],
#       dtype='object')

# %% [markdown]
# Analysing Textual data

# %%
# Libraries for text processing
import re, nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords

def clean_tokenized_sentence(s):
    """Performs basic cleaning of a tokenized sentence"""
    cleaned_s = ""  # Create empty string to store processed sentence.
    words = nltk.word_tokenize(s)
    for word in words:
        # Convert to lowercase #
        c_word = word.lower()
        # Remove punctuations #
        c_word = re.sub(r'[^\w\s]', '', c_word)
        # Remove stopwords #
        if c_word != '' and c_word not in stopwords.words('english'):
            cleaned_s = cleaned_s + " " + c_word    # Append processed words to new list.
    return(cleaned_s.strip())
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# creating new dataframe for analysis
df_text=preprocessed_data_df[['project_title','essay','project_is_approved']]
df_text.head(2)
# Out:
#                                       project_title  \
# 0  Educational Support for English Learners at Home
# 1             Wanted: Projector for Hungry Learners
#
#                                                essay  project_is_approved
# 0  My students are English learners that are work...                    0
# 1  Our students arrive to our school eager to lea...                    1

# %%
# df_text.to_csv("/content/drive/MyDrive/DSML/Business Case Study/Portfolio/1.DS_Portfolio/df_textUpdated.csv",index=False)

# %%
df_text=pd.read_csv("/content/drive/MyDrive/DSML/Business Case Study/Portfolio/1.DS_Portfolio/df_textUpdated.csv")

# %%
df_text.head(2)
# Out:
#                                       project_title  \
# 0  Educational Support for English Learners at Home
# 1             Wanted: Projector for Hungry Learners
#
#                                                essay  project_is_approved  \
# 0  My students are English learners that are work...                    0
# 1  Our students arrive to our school eager to lea...                    1
#
#                                        essay_message  \
# 0  students english learners working english seco...
# 1  students arrive school eager learn polite gene...
#
#                        project_title_message  \
# 0  educational support english learners home
# 1           wanted projector hungry learners
#
#                             project_resource_summary
# 0  students need opportunities practice beginning...
# 1  students need projector help viewing education...

# %%
# df_text["essay_message"] = df_text["essay"].apply(clean_tokenized_sentence)
# df_text.head(2)
# Out:
# <ipython-input-146-6d8352e0f80d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_text["essay_message"] = df_text["essay"].apply(clean_tokenized_sentence)
#                                       project_title  \
# 0  Educational Support for English Learners at Home
# 1             Wanted: Projector for Hungry Learners
#
#                                                essay  project_is_approved  \
# 0  My students are English learners that are work...                    0
# 1  Our students arrive to our school eager to lea...                    1
#
#                                        essay_message
# 0  students english learners working english seco...
# 1  students arrive school eager learn polite gene...

# %%
# Analysing top words from eassy in approved project
# selecting approved essay
approved=df_text[df_text["project_is_approved"]==1]["essay_message"]
# clubbing all text data
approved = " ".join(approved)
#Now Splitting the entire text into words
approved=approved.split()
 #Finding the top 40 words mostly used in approved
from collections import Counter
counter_approved = Counter(approved).most_common(50)
counter_approved
# Out:
# [('students', 667732),
#  ('school', 210627),
#  ('learning', 145059),
#  ('classroom', 141774),
#  ('learn', 104233),
#  ('help', 103326),
#  ('many', 87417),
#  ('need', 78479),
#  ('work', 77772),
#  ('reading', 76688),
#  ('use', 73910),
#  ('love', 67360),
#  ('able', 65384),
#  ('come', 63347),
#  ('day', 62185),
#  ('class', 61298),
#  ('would', 59336),
#  ('also', 56088),
#  ('technology', 55660),
#  ('books', 55104),
#  ('skills', 53539),
#  ('new', 53389),
#  ('make', 50566),
#  ('year', 50228),
#  ('want', 49195),
#  ('time', 47652),
#  ('student', 46417),
#  ('one', 45124),
#  ('grade', 43944),
#  ('get', 41694),
#  ('allow', 41579),
#  ('math', 40298),
#  ('read', 40102),
#  ('every', 40041),
#  ('provide', 39548),
#  ('children', 38455),
#  ('materials', 36929),
#  ('teach', 35548),
#  ('different', 34286),
#  ('world', 33539),
#  ('like', 33197),
#  ('project', 32691),
#  ('create', 31366),
#  ('group', 31179),
#  ('best', 30758),
#  ('way', 30627),
#  ('learners', 30309),
#  ('nt', 29722),
#  ('access', 29684),
#  ('needs', 29592)]

# %%
# Extracting word and frequency for plotting
top_words = [word for word, freq in counter_approved]
word_freq = [freq for word, freq in counter_approved]

# Plotting the top words
plt.figure(figsize=(10, 6))
plt.bar(top_words, word_freq)
plt.xticks(rotation=90)
plt.xlabel('Top Words')
plt.ylabel('Frequency')
plt.title('Top Words in Approved Essays')
plt.tight_layout()
plt.show()

# %%
# Analysing top words from eassy in not approved project
# selecting approved essay
not_approved=df_text[df_text["project_is_approved"]==0]["essay_message"]
# clubbing all text data
not_approved = " ".join(not_approved)
#Now Splitting the entire text into words
not_approved=not_approved.split()
 #Finding the top 40 words mostly used in approved
from collections import Counter
counter_not_approved = Counter(not_approved).most_common(50)
counter_not_approved
# Out:
# [('students', 111411),
#  ('school', 37104),
#  ('learning', 26706),
#  ('classroom', 22775),
#  ('learn', 18896),
#  ('help', 18494),
#  ('many', 14807),
#  ('need', 13609),
#  ('work', 13030),
#  ('come', 11277),
#  ('love', 10765),
#  ('able', 10508),
#  ('reading', 10325),
#  ('materials', 10319),
#  ('use', 10099),
#  ('skills', 9999),
#  ('day', 9659),
#  ('class', 9619),
#  ('want', 9558),
#  ('year', 9120),
#  ('make', 9104),
#  ('new', 8946),
#  ('would', 8743),
#  ('also', 8526),
#  ('technology', 8072),
#  ('student', 8020),
#  ('time', 7523),
#  ('one', 7302),
#  ('math', 7274),
#  ('children', 7181),
#  ('get', 7180),
#  ('grade', 6925),
#  ('provide', 6786),
#  ('project', 6356),
#  ('different', 6314),
#  ('every', 6256),
#  ('teach', 6141),
#  ('supplies', 6060),
#  ('best', 6033),
#  ('allow', 5963),
#  ('world', 5897),
#  ('education', 5852),
#  ('create', 5790),
#  ('books', 5757),
#  ('like', 5696),
#  ('science', 5691),
#  ('needs', 5423),
#  ('activities', 5338),
#  ('way', 5315),
#  ('kids', 5313)]

# %%
# Extracting word and frequency for plotting
top_words = [word for word, freq in counter_not_approved]
word_freq = [freq for word, freq in counter_not_approved]

# Plotting the top words
plt.figure(figsize=(10, 6))
plt.bar(top_words, word_freq)
plt.xticks(rotation=90)
plt.xlabel('Top Words')
plt.ylabel('Frequency')
plt.title('Top Words in not Approved Essays')
plt.tight_layout()
plt.show()

# %%
# calculating common top  50  words form the approved and disapproved words
top50_approved=[x[0] for x in counter_approved]
top50_notapproved=[x[0] for x in counter_not_approved]

intersection_words = list(set(top50_approved).intersection(top50_notapproved))

print(intersection_words)
print("len of intersection_words= ",len(intersection_words))
# Out:
# ['use', 'like', 'classroom', 'one', 'many', 'come', 'project', 'learn', 'make', 'help', 'different', 'year', 'get', 'work', 'also', 'provide', 'learning', 'time', 'books', 'day', 'need', 'class', 'reading', 'teach', 'children', 'math', 'want', 'best', 'students', 'create', 'needs', 'new', 'materials', 'technology', 'world', 'every', 'love', 'able', 'school', 'student', 'grade', 'would', 'way', 'skills', 'allow']
# len of intersection_words=  45

# %%
'''
As per the analysis there 45 words which are common between approved and not approved essays
'''

# %% [markdown]
# Analysing project title data

# %%
df_text["project_title_message"] = df_text["project_title"].apply(clean_tokenized_sentence)
# df_text.head(2)

# %%
# Analysing top words from project_title in approved project
# selecting approved project_title
approved_title=df_text[df_text["project_is_approved"]==1]["project_title_message"]
# clubbing all text data
approved_title = " ".join(approved_title)
#Now Splitting the entire text into words
approved_title=approved_title.split()
 #Finding the top 40 words mostly used in approved
from collections import Counter
counter_approved_title = Counter(approved_title).most_common(50)
counter_approved_title
# Out:
# [('learning', 7816),
#  ('technology', 5076),
#  ('classroom', 4760),
#  ('students', 4317),
#  ('reading', 4163),
#  ('help', 3776),
#  ('books', 3718),
#  ('seating', 3247),
#  ('need', 3222),
#  ('flexible', 2623),
#  ('math', 2595),
#  ('us', 2561),
#  ('learn', 2484),
#  ('read', 2212),
#  ('chromebooks', 2153),
#  ('supplies', 2043),
#  ('grade', 1950),
#  ('science', 1926),
#  ('let', 1916),
#  ('fun', 1790),
#  ('readers', 1772),
#  ('learners', 1724),
#  ('get', 1594),
#  ('success', 1565),
#  ('stem', 1552),
#  ('world', 1548),
#  ('art', 1510),
#  ('new', 1468),
#  ('kids', 1452),
#  ('work', 1441),
#  ('move', 1431),
#  ('school', 1403),
#  ('literacy', 1391),
#  ('wiggle', 1385),
#  ('time', 1365),
#  ('class', 1337),
#  ('book', 1320),
#  ('kindergarten', 1308),
#  ('future', 1302),
#  ('love', 1248),
#  ('ipads', 1244),
#  ('active', 1182),
#  ('library', 1177),
#  ('minds', 1159),
#  ('needs', 1159),
#  ('building', 1158),
#  ('graders', 1102),
#  ('make', 1095),
#  ('making', 1091),
#  ('first', 1074)]

# %%
# Extracting word and frequency for plotting
top_words = [word for word, freq in counter_approved_title]
word_freq = [freq for word, freq in counter_approved_title]

# Plotting the top words
plt.figure(figsize=(10, 6))
plt.bar(top_words, word_freq)
plt.xticks(rotation=90)
plt.xlabel('Top Words')
plt.ylabel('Frequency')
plt.title('Top Words in not Approved  Project title')
plt.tight_layout()
plt.show()

# %%
# Analysing top words from project_title in not approved project
# selecting approved project_title
not_approved_title=df_text[df_text["project_is_approved"]==0]["project_title_message"]
# clubbing all text data
not_approved_title = " ".join(not_approved_title)
#Now Splitting the entire text into words
not_approved_title=not_approved_title.split()
 #Finding the top 40 words mostly used in approved
from collections import Counter
counter_not_approved_title = Counter(not_approved_title).most_common(50)
counter_not_approved_title
# Out:
# [('learning', 1455),
#  ('classroom', 898),
#  ('students', 776),
#  ('technology', 758),
#  ('seating', 717),
#  ('math', 660),
#  ('reading', 656),
#  ('help', 636),
#  ('supplies', 636),
#  ('flexible', 635),
#  ('science', 498),
#  ('learn', 475),
#  ('need', 470),
#  ('stem', 436),
#  ('fun', 431),
#  ('us', 404),
#  ('grade', 381),
#  ('books', 378),
#  ('art', 378),
#  ('let', 375),
#  ('read', 358),
#  ('school', 330),
#  ('new', 290),
#  ('learners', 289),
#  ('success', 279),
#  ('get', 277),
#  ('future', 276),
#  ('play', 267),
#  ('world', 259),
#  ('kids', 254),
#  ('class', 246),
#  ('kindergarten', 245),
#  ('needs', 242),
#  ('building', 240),
#  ('literacy', 240),
#  ('minds', 235),
#  ('hands', 233),
#  ('make', 226),
#  ('readers', 226),
#  ('move', 219),
#  ('time', 215),
#  ('making', 212),
#  ('steam', 212),
#  ('materials', 211),
#  ('love', 210),
#  ('student', 197),
#  ('sensory', 195),
#  ('work', 194),
#  ('first', 188),
#  ('life', 187)]

# %%
# Extracting word and frequency for plotting
top_words = [word for word, freq in counter_not_approved_title]
word_freq = [freq for word, freq in counter_not_approved_title]

# Plotting the top words
plt.figure(figsize=(10, 6))
plt.bar(top_words, word_freq)
plt.xticks(rotation=90)
plt.xlabel('Top Words')
plt.ylabel('Frequency')
plt.title('Top Words in not Approved  Project title')
plt.tight_layout()
plt.show()

# %%
# calculating common top  50  words form the approved and disapproved words
top50_approved_title=[x[0] for x in counter_approved]
top50_not_approved_title=[x[0] for x in counter_not_approved]
intersection_words_title = list(set(top50_approved_title).intersection(top50_not_approved_title))

print(intersection_words_title)
print("len of intersection_words= ",len(intersection_words_title))
# Out:
# ['use', 'like', 'classroom', 'one', 'many', 'come', 'project', 'learn', 'make', 'help', 'different', 'year', 'get', 'work', 'also', 'provide', 'learning', 'time', 'books', 'day', 'need', 'class', 'reading', 'teach', 'children', 'math', 'want', 'best', 'students', 'create', 'needs', 'new', 'materials', 'technology', 'world', 'every', 'love', 'able', 'school', 'student', 'grade', 'would', 'way', 'skills', 'allow']
# len of intersection_words=  45

# %%
'''
As per the analysis there 45 words which are common between approved and not approved title
'''

# %% [markdown]
# Analysing project project_resource_summary data

# %%
# df_text["project_resource_summary_message"] = df_text["project_resource_summary"].apply(clean_tokenized_sentence)

# df_text["project_resource_summary"]=df_text["project_resource_summary_message"]
# df_text.head(2)
# Out:
#                                       project_title  \
# 0  Educational Support for English Learners at Home
# 1             Wanted: Projector for Hungry Learners
#
#                                                essay  project_is_approved  \
# 0  My students are English learners that are work...                    0
# 1  Our students arrive to our school eager to lea...                    1
#
#                                        essay_message  \
# 0  students english learners working english seco...
# 1  students arrive school eager learn polite gene...
#
#                        project_title_message  \
# 0  educational support english learners home
# 1           wanted projector hungry learners
#
#                             project_resource_summary
# 0  students need opportunities practice beginning...
# 1  students need projector help viewing education...

# %%
# Analysing top words from project_resource_summary in approved project
# selecting approved essay
approved_project_resource_summary=df_text[df_text["project_is_approved"]==1]["project_resource_summary"]
# clubbing all text data
approved_project_resource_summary = " ".join(approved_project_resource_summary)
#Now Splitting the entire text into words
approved_project_resource_summary=approved_project_resource_summary.split()
 #Finding the top 40 words mostly used in approved
from collections import Counter
counter_approved_project_resource_summary = Counter(approved_project_resource_summary).most_common(50)
counter_approved_project_resource_summary
# Out:
# [('students', 101146),
#  ('need', 97496),
#  ('classroom', 15152),
#  ('help', 14598),
#  ('learning', 14390),
#  ('books', 12585),
#  ('reading', 11184),
#  ('math', 7015),
#  ('use', 6859),
#  ('skills', 6671),
#  ('learn', 6327),
#  ('technology', 6142),
#  ('seating', 5881),
#  ('work', 5629),
#  ('class', 5602),
#  ('materials', 5319),
#  ('supplies', 5004),
#  ('school', 4958),
#  ('chairs', 4930),
#  ('chromebooks', 4668),
#  ('new', 4596),
#  ('order', 4399),
#  ('ipad', 4072),
#  ('science', 4059),
#  ('access', 4038),
#  ('create', 3864),
#  ('read', 3725),
#  ('set', 3691),
#  ('allow', 3344),
#  ('keep', 3310),
#  ('wobble', 3246),
#  ('activities', 3191),
#  ('flexible', 3176),
#  ('time', 3145),
#  ('headphones', 3036),
#  ('ipads', 3017),
#  ('able', 3006),
#  ('make', 2978),
#  ('balls', 2975),
#  ('stools', 2966),
#  ('book', 2938),
#  ('projects', 2838),
#  ('writing', 2822),
#  ('paper', 2821),
#  ('center', 2803),
#  ('practice', 2743),
#  ('library', 2736),
#  ('enhance', 2716),
#  ('art', 2622),
#  ('literacy', 2573)]

# %%
# Extracting word and frequency for plotting
top_words = [word for word, freq in counter_approved_project_resource_summary]
word_freq = [freq for word, freq in counter_approved_project_resource_summary]

# Plotting the top words
plt.figure(figsize=(10, 6))
plt.bar(top_words, word_freq)
plt.xticks(rotation=90)
plt.xlabel('Top Words')
plt.ylabel('Frequency')
plt.title('Top Words in Approved project_resource_summary')
plt.tight_layout()
plt.show()

# %%
# Analysing top words from eassy in not approved project
# selecting approved essay
not_approved_project_resource_summary=df_text[df_text["project_is_approved"]==0]["project_resource_summary"]
# clubbing all text data
not_approved_project_resource_summary = " ".join(not_approved_project_resource_summary)
#Now Splitting the entire text into words
not_approved_project_resource_summary=not_approved_project_resource_summary.split()
 #Finding the top 40 words mostly used in approved
from collections import Counter
counter_not_approved_project_resource_summary = Counter(not_approved_project_resource_summary).most_common(50)
counter_not_approved_project_resource_summary
# Out:
# [('students', 18371),
#  ('need', 17689),
#  ('help', 3013),
#  ('learning', 2966),
#  ('classroom', 2627),
#  ('materials', 2134),
#  ('supplies', 2098),
#  ('books', 1727),
#  ('reading', 1656),
#  ('math', 1577),
#  ('skills', 1344),
#  ('seating', 1334),
#  ('learn', 1277),
#  ('technology', 1122),
#  ('school', 1086),
#  ('work', 1022),
#  ('science', 1006),
#  ('activities', 1003),
#  ('use', 1001),
#  ('create', 912),
#  ('class', 841),
#  ('items', 801),
#  ('order', 801),
#  ('new', 780),
#  ('flexible', 770),
#  ('art', 759),
#  ('games', 715),
#  ('equipment', 686),
#  ('make', 666),
#  ('hands', 649),
#  ('able', 615),
#  ('options', 611),
#  ('chairs', 602),
#  ('stem', 588),
#  ('access', 587),
#  ('variety', 582),
#  ('allow', 582),
#  ('paper', 564),
#  ('read', 559),
#  ('also', 557),
#  ('projects', 548),
#  ('writing', 547),
#  ('keep', 538),
#  ('tools', 535),
#  ('year', 531),
#  ('center', 523),
#  ('time', 521),
#  ('ipad', 510),
#  ('fun', 509),
#  ('enhance', 502)]

# %%
# Extracting word and frequency for plotting
top_words = [word for word, freq in counter_not_approved_project_resource_summary]
word_freq = [freq for word, freq in counter_not_approved_project_resource_summary]

# Plotting the top words
plt.figure(figsize=(10, 6))
plt.bar(top_words, word_freq)
plt.xticks(rotation=90)
plt.xlabel('Top Words')
plt.ylabel('Frequency')
plt.title('Top Words in not Approved project_resource_summary')
plt.tight_layout()
plt.show()

# %%
# calculating common top  50  words form the approved and disapproved words

top50_approved_project_resource_summary=[x[0] for x in counter_approved_project_resource_summary]
top50_not_approved_project_resource_summary=[x[0] for x in counter_not_approved_project_resource_summary]

intersection_words_title = list(set(top50_approved_project_resource_summary).intersection(top50_not_approved_project_resource_summary))

print(intersection_words_title)
print("len of intersection_words= ",len(intersection_words_title))
# Out:
# ['class', 'time', 'skills', 'keep', 'students', 'school', 'new', 'science', 'access', 'use', 'writing', 'need', 'make', 'technology', 'enhance', 'learning', 'chairs', 'learn', 'work', 'supplies', 'materials', 'center', 'seating', 'projects', 'read', 'order', 'classroom', 'activities', 'books', 'allow', 'ipad', 'art', 'help', 'paper', 'create', 'able', 'flexible', 'reading', 'math']
# len of intersection_words=  39

# %%
'''
As per the analysis there 39 words which are common between approved and not approved tile
'''

# %%
df_text.head(2)
# Out:
#                                       project_title  \
# 0  Educational Support for English Learners at Home
# 1             Wanted: Projector for Hungry Learners
#
#                                                essay  project_is_approved  \
# 0  My students are English learners that are work...                    0
# 1  Our students arrive to our school eager to lea...                    1
#
#                                        essay_message  \
# 0  students english learners working english seco...
# 1  students arrive school eager learn polite gene...
#
#                        project_title_message
# 0  educational support english learners home
# 1           wanted projector hungry learners

# %%
# df_text.to_csv("/content/drive/MyDrive/DSML/Business Case Study/Portfolio/1.DS_Portfolio/df_textUpdated.csv",index=False)

# %%
preprocessed_data_df=pd.read_csv("/content/drive/MyDrive/DSML/Business Case Study/Portfolio/1.DS_Portfolio/preprocessed_data_df_updated.csv")

# %%
preprocessed_data_df.head(2)
# Out:
#   teacher_prefix school_state  \
# 0            mrs           in
# 1             mr           fl
#
#                                        project_title  \
# 0  students english learners working english seco...
# 1  students arrive school eager learn polite gene...
#
#                             project_resource_summary  \
# 0  My students need opportunities to practice beg...
# 1  My students need a projector to help with view...
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                             0                    0
# 1                                             7                    1
#
#      project_subject_categories  project_subject_subcategories  \
# 0             literacy_language                   esl literacy
# 1  history_civics health_sports  civics_government team_sports
#
#   project_grade_category                                              essay  \
# 0          grades_prek_2  students english learners working english seco...
# 1             grades_6_8  students arrive school eager learn polite gene...
#
#    price  quantity
# 0  154.6        23
# 1  299.0         1

# %%
preprocessed_data_df=pd.read_csv("/content/drive/MyDrive/DSML/Business Case Study/Portfolio/1.DS_Portfolio/final_preprocessed_data_df.csv")
preprocessed_data_df.head(2)
# Out:
#   teacher_prefix school_state  \
# 0            mrs           in
# 1             mr           fl
#
#                                       project_title  \
# 0  Educational Support for English Learners at Home
# 1             Wanted: Projector for Hungry Learners
#
#                             project_resource_summary  \
# 0  My students need opportunities to practice beg...
# 1  My students need a projector to help with view...
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                             0                    0
# 1                                             7                    1
#
#      project_subject_categories  project_subject_subcategories  \
# 0             literacy_language                   esl literacy
# 1  history_civics health_sports  civics_government team_sports
#
#   project_grade_category                                              essay  \
# 0          grades_prek_2  My students are English learners that are work...
# 1             grades_6_8  Our students arrive to our school eager to lea...
#
#    price  quantity
# 0  154.6        23
# 1  299.0         1

# %%
# replacing processed title and essay with pre-processed respectively
preprocessed_data_df["essay"]=df_text["essay_message"]
preprocessed_data_df["project_title"]=df_text["essay_message"]

preprocessed_data_df.head(5)
# Out:
#   teacher_prefix school_state  \
# 0            mrs           in
# 1             mr           fl
# 2             ms           az
# 3            mrs           ky
# 4            mrs           tx
#
#                                        project_title  \
# 0  students english learners working english seco...
# 1  students arrive school eager learn polite gene...
# 2  true champions nt always ones win guts mia ham...
# 3  work unique school filled esl english second l...
# 4  second grade classroom next year made around 2...
#
#                             project_resource_summary  \
# 0  My students need opportunities to practice beg...
# 1  My students need a projector to help with view...
# 2  My students need shine guards, athletic socks,...
# 3  My students need to engage in Reading and Math...
# 4  My students need hands on practice in mathemat...
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                             0                    0
# 1                                             7                    1
# 2                                             1                    0
# 3                                             4                    1
# 4                                             1                    1
#
#        project_subject_categories  project_subject_subcategories  \
# 0               literacy_language                   esl literacy
# 1    history_civics health_sports  civics_government team_sports
# 2                   health_sports    health_wellness team_sports
# 3  literacy_language math_science           literacy mathematics
# 4                    math_science                    mathematics
#
#   project_grade_category                                              essay  \
# 0          grades_prek_2  students english learners working english seco...
# 1             grades_6_8  students arrive school eager learn polite gene...
# 2             grades_6_8  true champions nt always ones win guts mia ham...
# 3          grades_prek_2  work unique school filled esl english second l...
# 4          grades_prek_2  second grade classroom next year made around 2...
#
#     price  quantity
# 0  154.60        23
# 1  299.00         1
# 2  516.85        22
# 3  232.90         4
# 4   67.98         4

# %% [markdown]
# **Splitting Data into train,test and val**

# %%
preprocessed_data_df.columns
# Out:
# Index(['teacher_prefix', 'school_state', 'project_title',
#        'project_resource_summary',
#        'teacher_number_of_previously_posted_projects', 'project_is_approved',
#        'project_subject_categories', 'project_subject_subcategories',
#        'project_grade_category', 'essay', 'price', 'quantity'],
#       dtype='object')

# %%
new_df=preprocessed_data_df[['teacher_prefix', 'school_state', 'project_title','project_resource_summary',
       'teacher_number_of_previously_posted_projects', 'project_is_approved',
       'project_subject_categories', 'project_subject_subcategories',
       'project_grade_category', 'essay', 'price', 'quantity']]

# %%
# splitting data to X,Y and val data
from sklearn.model_selection import train_test_split
X,x_val,Y,y_val=train_test_split(
    new_df,
    new_df['project_is_approved'],
    test_size=0.2,
    random_state=42,
    stratify=preprocessed_data_df[['project_is_approved']])

# %%
print("x_train: ",X.shape)
print("x_test : ",x_val.shape)
print("y_train: ",Y.shape)
print("y_test : ",y_val.shape)
# Out:
# x_train:  (87396, 12)
# x_test :  (21849, 12)
# y_train:  (87396,)
# y_test :  (21849,)

# %%
# splitting data to trai,val and test split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, stratify=Y)

print("x_train: ",x_train.shape)
print("y_train: ",y_train.shape)
print("x_val   : ",x_val.shape)
print("x_val   : ",y_val.shape)
print("x_test : ",x_test.shape)
print("y_test : ",y_test.shape)
# Out:
# x_train:  (65547, 12)
# y_train:  (65547,)
# x_val   :  (21849, 12)
# x_val   :  (21849,)
# x_test :  (21849, 12)
# y_test :  (21849,)

# %%
# y_value_counts = row1['project_is_approved'].value_counts()
print("X_TRAIN-------------------------")
x_train_y_value_counts = x_train['project_is_approved'].value_counts()
print("Number of projects that are approved for funding    ", x_train_y_value_counts[1]," -> ",round(x_train_y_value_counts[1]/(x_train_y_value_counts[1]+x_train_y_value_counts[0])*100,2),"%")
print("Number of projects that are not approved for funding ",x_train_y_value_counts[0]," -> ",round(x_train_y_value_counts[0]/(x_train_y_value_counts[1]+x_train_y_value_counts[0])*100,2),"%")
print("\n")
# y_value_counts = row1['project_is_approved'].value_counts()
print("X_TEST--------------------------")
x_test_y_value_counts = x_test['project_is_approved'].value_counts()
print("Number of projects that are approved for funding    ", x_test_y_value_counts[1]," -> ",round(x_test_y_value_counts[1]/(x_test_y_value_counts[1]+x_test_y_value_counts[0])*100,2),"%")
print("Number of projects that are not approved for funding ",x_test_y_value_counts[0]," -> ",round(x_test_y_value_counts[0]/(x_test_y_value_counts[1]+x_test_y_value_counts[0])*100,2),"%")
print("\n")

print("X_Val--------------------------")
x_val_y_value_counts = x_val['project_is_approved'].value_counts()
print("Number of projects that are approved for funding    ", x_val_y_value_counts[1]," -> ",round(x_val_y_value_counts[1]/(x_val_y_value_counts[1]+x_val_y_value_counts[0])*100,2),"%")
print("Number of projects that are not approved for funding ",x_val_y_value_counts[0]," -> ",round(x_val_y_value_counts[0]/(x_val_y_value_counts[1]+x_val_y_value_counts[0])*100,2),"%")
print("\n")
# Out:
# X_TRAIN-------------------------
# Number of projects that are approved for funding     55621  ->  84.86 %
# Number of projects that are not approved for funding  9926  ->  15.14 %
#
#
# X_TEST--------------------------
# Number of projects that are approved for funding     18541  ->  84.86 %
# Number of projects that are not approved for funding  3308  ->  15.14 %
#
#
# X_Val--------------------------
# Number of projects that are approved for funding     18541  ->  84.86 %
# Number of projects that are not approved for funding  3308  ->  15.14 %

# %% [markdown]
# **Handeling Categorical and text Data**

# %% [markdown]
# A) Handeling categorical data

# %%
# Vectorizing project subject categories
# we use count vectorizer to convert the values into one
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_sub = CountVectorizer(lowercase=False, binary=True)

vectorizer_sub.fit(x_train['project_subject_categories'].values)

x_train_project_subject_categories_one_hot = vectorizer_sub.transform(x_train['project_subject_categories'].values)

x_test_project_subject_categories_one_hot  = vectorizer_sub.transform(x_test['project_subject_categories'].values)

x_val_project_subject_categories_one_hot  = vectorizer_sub.transform(x_val['project_subject_categories'].values)


print("Shape of matrix after one hot encoding -> categories: x_train: ",x_train_project_subject_categories_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_val   : ",x_val_project_subject_categories_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_test : ",x_test_project_subject_categories_one_hot.shape)
# Out:
# Shape of matrix after one hot encoding -> categories: x_train:  (65547, 9)
# Shape of matrix after one hot encoding -> categories: x_val   :  (21849, 9)
# Shape of matrix after one hot encoding -> categories: x_test :  (21849, 9)

# %%
# Vectorizing project subject sub-categories
# we use count vectorizer to convert the values into one
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_sub_sub_category = CountVectorizer(lowercase=False, binary=True)

vectorizer_sub_sub_category.fit(x_train['project_subject_subcategories'].values)

x_train_project_subject_subcategories_one_hot = vectorizer_sub_sub_category.transform(x_train['project_subject_subcategories'].values)

x_test_project_subject_subcategories_one_hot  = vectorizer_sub_sub_category.transform(x_test['project_subject_subcategories'].values)

x_val_project_subject_subcategories_one_hot  = vectorizer_sub_sub_category.transform(x_val['project_subject_subcategories'].values)




print("Shape of matrix after one hot encoding -> categories: x_train: ",x_train_project_subject_subcategories_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_val   : ",x_val_project_subject_subcategories_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_test : ",x_test_project_subject_subcategories_one_hot.shape)
# Out:
# Shape of matrix after one hot encoding -> categories: x_train:  (65547, 30)
# Shape of matrix after one hot encoding -> categories: x_val   :  (21849, 30)
# Shape of matrix after one hot encoding -> categories: x_test :  (21849, 30)

# %%
# Vectorizing teacher_prefix
# we use count vectorizer to convert the values into one
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_teacher_prefix = CountVectorizer(lowercase=False, binary=True)

vectorizer_teacher_prefix.fit(x_train['teacher_prefix'].values)

x_train_teacher_prefix_one_hot = vectorizer_teacher_prefix.transform(x_train['teacher_prefix'].values)

x_test_teacher_prefix_one_hot  = vectorizer_teacher_prefix.transform(x_test['teacher_prefix'].values)

x_val_teacher_prefix_one_hot  = vectorizer_teacher_prefix.transform(x_val['teacher_prefix'].values)



print("Shape of matrix after one hot encoding -> categories: x_train: ",x_test_teacher_prefix_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_val   : ",x_val_teacher_prefix_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_test : ",x_test_teacher_prefix_one_hot.shape)
# Out:
# Shape of matrix after one hot encoding -> categories: x_train:  (21849, 5)
# Shape of matrix after one hot encoding -> categories: x_val   :  (21849, 5)
# Shape of matrix after one hot encoding -> categories: x_test :  (21849, 5)

# %%
# Vectorizing school_state
# we use count vectorizer to convert the values into one
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_school_state = CountVectorizer(lowercase=False, binary=True)

vectorizer_school_state.fit(x_train['school_state'].values)

x_train_school_state_one_hot = vectorizer_school_state.transform(x_train['school_state'].values)

x_test_school_state_one_hot  = vectorizer_school_state.transform(x_test['school_state'].values)

x_val_school_state_one_hot  = vectorizer_school_state.transform(x_val['school_state'].values)



print("Shape of matrix after one hot encoding -> categories: x_train: ",x_train_school_state_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_val   : ",x_val_school_state_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_test : ",x_test_school_state_one_hot.shape)
# Out:
# Shape of matrix after one hot encoding -> categories: x_train:  (65547, 51)
# Shape of matrix after one hot encoding -> categories: x_val   :  (21849, 51)
# Shape of matrix after one hot encoding -> categories: x_test :  (21849, 51)

# %%
# Vectorizing project_grade_category
# we use count vectorizer to convert the values into one
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_project_grade_category = CountVectorizer(lowercase=False, binary=True)

vectorizer_project_grade_category.fit(x_train['project_grade_category'].values)

x_train_project_grade_category_one_hot = vectorizer_project_grade_category.transform(x_train['project_grade_category'].values)

x_test_project_grade_category_one_hot  = vectorizer_project_grade_category.transform(x_test['project_grade_category'].values)

x_val_project_grade_category_one_hot  = vectorizer_project_grade_category.transform(x_val['project_grade_category'].values)



print("Shape of matrix after one hot encoding -> categories: x_train: ",x_train_project_grade_category_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_val   : ",x_val_project_grade_category_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_test : ",x_test_project_grade_category_one_hot.shape)
# Out:
# Shape of matrix after one hot encoding -> categories: x_train:  (65547, 4)
# Shape of matrix after one hot encoding -> categories: x_val   :  (21849, 4)
# Shape of matrix after one hot encoding -> categories: x_test :  (21849, 4)

# %% [markdown]
# Handeling text data|

# %% [markdown]
# 1) Creating tf-idf vectors for project title and essay

# %%
# Applying tf-IDF on project_title

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer_project_title_tfidf = TfidfVectorizer(min_df=10)
vectorizer_project_title_tfidf.fit(x_train['project_title'])
x_train_project_titles_tfidf = vectorizer_project_title_tfidf.transform(x_train['project_title'])
x_val_project_titles_tfidf    = vectorizer_project_title_tfidf.transform(x_val['project_title'])
x_test_project_titles_tfidf  = vectorizer_project_title_tfidf.transform(x_test['project_title'])

# %%
print("Shape of matrix after TF-IDF -> Title: x_train: ",x_train_project_titles_tfidf.shape)
print("Shape of matrix after TF-IDF -> Title: x_val  : ",x_val_project_titles_tfidf.shape)
print("Shape of matrix after TF-IDF -> Title: x_test : ",x_test_project_titles_tfidf.shape)
# Out:
# Shape of matrix after TF-IDF -> Title: x_train:  (65547, 2484)
# Shape of matrix after TF-IDF -> Title: x_val  :  (21849, 2484)
# Shape of matrix after TF-IDF -> Title: x_test :  (21849, 2484)

# %%
# Applying tf-IDF on essay
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer_essay_tfidf = TfidfVectorizer(min_df=10)
vectorizer_essay_tfidf.fit(x_train['essay'])
x_train_essay_tfidf = vectorizer_essay_tfidf.transform(x_train['essay'])
x_val_essay_tfidf = vectorizer_essay_tfidf.transform(x_val['essay'])

x_test_essay_tfidf  = vectorizer_essay_tfidf.transform(x_test['essay'])

print("Shape of matrix after TF-IDF -> Title: x_train: ",x_train_essay_tfidf.shape)
print("Shape of matrix after TF-IDF -> Title: x_val: ",x_val_essay_tfidf.shape)
print("Shape of matrix after TF-IDF -> Title: x_test : ",x_test_essay_tfidf.shape)
# Out:
# Shape of matrix after TF-IDF -> Title: x_train:  (65547, 13671)
# Shape of matrix after TF-IDF -> Title: x_val:  (21849, 13671)
# Shape of matrix after TF-IDF -> Title: x_test :  (21849, 13671)

# %% [markdown]
# 2)Applying CountVectorier  on essay and title

# %%
# Applying  countVectorizer on project_title
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_project_title_CountVectorizer = CountVectorizer(min_df=10,lowercase=False, binary=True)

vectorizer_project_title_CountVectorizer.fit(x_train['project_title'])
x_train_project_titles_CountVectorizer = vectorizer_project_title_CountVectorizer.transform(x_train['project_title'])
x_val_project_titles_CountVectorizer   = vectorizer_project_title_CountVectorizer.transform(x_val['project_title'])
x_test_project_titles_CountVectorizer  = vectorizer_project_title_CountVectorizer.transform(x_test['project_title'])

print("Shape of matrix after TF-IDF -> Title: x_train: ",x_train_project_titles_CountVectorizer.shape)
print("Shape of matrix after TF-IDF -> Title: x_val  : ",x_val_project_titles_CountVectorizer.shape)
print("Shape of matrix after TF-IDF -> Title: x_test : ",x_test_project_titles_CountVectorizer.shape)
# Out:
# Shape of matrix after TF-IDF -> Title: x_train:  (65547, 2804)
# Shape of matrix after TF-IDF -> Title: x_val  :  (21849, 2804)
# Shape of matrix after TF-IDF -> Title: x_test :  (21849, 2804)

# %%
# Applying  countVectorizer on project_essay

from sklearn.feature_extraction.text import CountVectorizer
vectorizer_project_essay_CountVectorizer = CountVectorizer(min_df=10,lowercase=False, binary=True)
vectorizer_project_essay_CountVectorizer.fit(x_train['essay'])

x_train_essay_CountVectorizer = vectorizer_project_essay_CountVectorizer.transform(x_train['essay'])
x_val_essay_CountVectorizer = vectorizer_project_essay_CountVectorizer.transform(x_val['essay'])

x_test_essay_CountVectorizer  = vectorizer_project_essay_CountVectorizer.transform(x_test['essay'])

print("Shape of matrix after TF-IDF -> Title: x_train: ",x_train_essay_CountVectorizer.shape)
print("Shape of matrix after TF-IDF -> Title: x_val: ",x_val_essay_CountVectorizer.shape)
print("Shape of matrix after TF-IDF -> Title: x_test : ",x_test_essay_CountVectorizer.shape)
# Out:
# Shape of matrix after TF-IDF -> Title: x_train:  (65547, 16162)
# Shape of matrix after TF-IDF -> Title: x_val:  (21849, 16162)
# Shape of matrix after TF-IDF -> Title: x_test :  (21849, 16162)

# %%
# Vectorizing project project_resource_summary categories
# we use count vectorizer to convert the values into one
from sklearn.feature_extraction.text import CountVectorizer
vectorizer_resource_summary = CountVectorizer(lowercase=False, binary=True)

vectorizer_resource_summary.fit(x_train['project_resource_summary'].values)

x_train_project_resource_summary_one_hot = vectorizer_resource_summary.transform(x_train['project_resource_summary'].values)

x_test_project_resource_summary_one_hot  = vectorizer_resource_summary.transform(x_test['project_resource_summary'].values)

x_val_project_resource_summary_one_hot  = vectorizer_resource_summary.transform(x_val['project_resource_summary'].values)




print("Shape of matrix after one hot encoding -> categories: x_train: ",x_train_project_resource_summary_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_val   : ",x_val_project_resource_summary_one_hot.shape)
print("Shape of matrix after one hot encoding -> categories: x_test : ",x_test_project_resource_summary_one_hot.shape)
# Out:
# Shape of matrix after one hot encoding -> categories: x_train:  (65547, 23685)
# Shape of matrix after one hot encoding -> categories: x_val   :  (21849, 23685)
# Shape of matrix after one hot encoding -> categories: x_test :  (21849, 23685)

# %% [markdown]
# 3)Standardizing Numerical features

# %% [markdown]
# A) Normalization of numerical data

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()
# scaler_transform_numerical_value.fit(x_train[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])
# df[["x","y","z"]]=x_train_teacher_number_of_previously_posted_projects_scaler=scaler_transform_numerical_value.transform(x_train[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])


normalizer.fit(x_train[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])

x_train[['teacher_number_of_previously_posted_projects', 'price',  'quantity']]=normalizer.transform(x_train[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])
x_test[['teacher_number_of_previously_posted_projects', 'price',  'quantity']]=normalizer.transform(x_test[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])
x_val[['teacher_number_of_previously_posted_projects', 'price',  'quantity']]=normalizer.transform(x_val[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])

# %% [markdown]
# B) Standadization of numerical data

# %%
from sklearn.preprocessing import StandardScaler
scaler_transform_numerical_value = StandardScaler()
scaler_transform_numerical_value.fit(x_train[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])

x_train[['teacher_number_of_previously_posted_projects', 'price',  'quantity']]=scaler_transform_numerical_value.transform(x_train[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])
x_test[['teacher_number_of_previously_posted_projects', 'price',  'quantity']]=scaler_transform_numerical_value.transform(x_test[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])
x_val[['teacher_number_of_previously_posted_projects', 'price',  'quantity']]=scaler_transform_numerical_value.transform(x_val[['teacher_number_of_previously_posted_projects', 'price',  'quantity']])

# %% [markdown]
# **Machine Learning Model Training**

# %%
'''
Note :- 1)Following models were trainined on the personal computers
        2) As per the analysis CountVectorizer provides good results

'''

# %% [markdown]
# 1) Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
import pickle
from sklearn.metrics import accuracy_score,classification_report,roc_auc_score, roc_curve,precision_recall_curve,auc,confusion_matrix

from scipy.sparse import hstack

# %%
x_train_onehot = hstack((x_train_project_subject_categories_one_hot,
                         x_train_project_subject_subcategories_one_hot   ,
                         x_train_teacher_prefix_one_hot    ,
                         x_train_school_state_one_hot  ,
                         x_train_project_grade_category_one_hot  ,
                         x_train_project_resource_summary_one_hot,
                         x_train_project_titles_tfidf  ,
                         x_train_essay_tfidf,
                         x_train[['teacher_number_of_previously_posted_projects', 'price',  'quantity']]))


print(x_train_onehot.shape)

# merging test value
x_test_onehot = hstack((x_test_project_subject_categories_one_hot,
                         x_test_project_subject_subcategories_one_hot   ,
                         x_test_teacher_prefix_one_hot    ,
                         x_test_school_state_one_hot  ,
                         x_test_project_grade_category_one_hot  ,
                         x_test_project_resource_summary_one_hot,
                         x_test_project_titles_tfidf  ,
                         x_test_essay_tfidf,
                         x_test[['teacher_number_of_previously_posted_projects', 'price',  'quantity']]))

# merging test value
x_val_onehot = hstack((x_val_project_subject_categories_one_hot,
                         x_val_project_subject_subcategories_one_hot   ,
                         x_val_teacher_prefix_one_hot    ,
                         x_val_school_state_one_hot  ,
                         x_val_project_grade_category_one_hot  ,
                         x_val_project_resource_summary_one_hot,
                         x_val_project_titles_tfidf  ,
                         x_val_essay_tfidf,
                         x_val[['teacher_number_of_previously_posted_projects', 'price',  'quantity']]))
# Out:
# (65547, 39942)

# %%
## following parameters choose after perfoeming hyperparameter tuning
# classifier = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced_subsample')
# classifier.fit(x_train_onehot, y_train)
# Predictiion on test data
# pred_xgboost=classifier.predict(x_test_onehot)
# pred_xgboost_train = classifier.predict(x_train_onehot)


# #Checking different metrics for bagging model with default hyper parameters
# print('Checking different metrics for bagging model with default hyper parameters:\n')
# print("Training accuracy: ",classifier.score(x_train_onehot,y_train))
# acc_score = accuracy_score(y_test, pred_xgboost)
# print('Testing accuracy: ',acc_score)
# conf_mat = confusion_matrix(y_test, pred_xgboost)
# print('Confusion Matrix: \n',conf_mat)
# roc_auc = roc_auc_score(y_test,pred_xgboost)
# print('ROC AUC score: ',roc_auc)
# class_rep_xgboost= classification_report(y_test,pred_xgboost)
# print('Classification Report: \n',class_rep_xgboost)

# %% [markdown]
# ![rfRsults.JPG](data:image/jpeg;base64,...)

# %%
'''
As per the analysis, the roc auc curve is 0.5 which means the model is not able to distinguish between 1 and 0
'''

# %% [markdown]
# 2) Xgboost Classifier

# %%
# from xgboost import XGBClassifier
# # following parameters choose after perfoeming hyperparameter tuning
# classifier = XGBClassifier(scale_pos_weight=0.17999,n_estimators=1000,learning_rate=0.01)
# # Fit the clas  sifier to the preprocessed training data
# classifier.fit(x_train_onehot, y_train)
# pred_xgboost_train = classifier.predict(x_train_onehot)
# print()
# print("Testing Score")

# #Checking different metrics for bagging model with default hyper parameters
# print('Checking different metrics for bagging model with default hyper parameters:\n')
# print("Training accuracy: ",classifier.score(x_train_onehot,y_train))
# acc_score = accuracy_score(y_test, pred_xgboost)
# print('Testing accuracy: ',acc_score)
# conf_mat = confusion_matrix(y_test, pred_xgboost)
# print('Confusion Matrix: \n',conf_mat)
# roc_auc = roc_auc_score(y_test,pred_xgboost)
# print('ROC AUC score: ',roc_auc)
# class_rep_xgboost= classification_report(y_test,pred_xgboost)
# print('Classification Report: \n',class_rep_xgboost)

# print()
# print("Validation Score")
# pred_xgboost=classifier.predict(x_val_onehot)
# pred_xgboost_train = classifier.predict(x_train_onehot)


# #Checking different metrics for bagging model with default hyper parameters
# print('Checking different metrics for bagging model with default hyper parameters:\n')
# print("Training accuracy: ",classifier.score(x_train_onehot,y_train))
# acc_score = accuracy_score(y_test, pred_xgboost)
# print('Testing accuracy: ',acc_score)
# conf_mat = confusion_matrix(y_test, pred_xgboost)
# print('Confusion Matrix: \n',conf_mat)
# roc_auc = roc_auc_score(y_test,pred_xgboost)
# print('ROC AUC score: ',roc_auc)
# class_rep_xgboost= classification_report(y_test,pred_xgboost)
# print('Classification Report: \n',class_rep_xgboost)

# %% [markdown]
# ![XgboostResult.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# 3) Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import  GridSearchCV

# %%
'''
The Naive Bayes model were trainined before hyperparameter tunning
and it provides roc_auc score of 0.70
'''

# %%
# Trainig Naive Bayes along nwith hyperparmter tunning
# # mnb_bow = MultinomialNB(class_prior=[0.5, 0.5])
# mnb_bow = MultinomialNB(class_prior=[0.8, 0.2])

# parameters = {'alpha':[0.00001, 0.00005, 0.0001, 0.0005, 0.001, 0.005, 0.01, 0.05, 0.5,0.6,0.7,0.8,0.9, 1, 5, 10, 50, 100, 500, 1000, 2500, 5000, 10000]}
# clf = GridSearchCV(mnb_bow, parameters, cv= 10, scoring='roc_auc',verbose=1,return_train_score=True)
# # clf.fit(x_cv_onehot_bow, y_cv)
# clf.fit(x_train_onehot,y_train)
# train_auc= clf.cv_results_['mean_train_score']
# train_auc_std= clf.cv_results_['std_train_score']
# cv_auc = clf.cv_results_['mean_test_score']
# cv_auc_std= clf.cv_results_['std_test_score']
# bestAlpha_1=clf.best_params_['alpha']
# bestScore_1=clf.best_score_
# print("BEST ALPHA: ",clf.best_params_['alpha']," BEST SCORE: ",clf.best_score_)

# mnb_bow_testModel = MultinomialNB(alpha = bestAlpha_1,class_prior=[0.5, 0.5])
# # class_prior is used for balancing the class
# mnb_bow_testModel.fit(x_train_onehot, y_train)

# %% [markdown]
# ![NavieBayesResults.JPG](data:image/jpeg;base64,...)

# %%
# Test data Confusion matrix

# %% [markdown]
# ![TestConfusion.png](data:image/png;base64,...)

# %%
# Test data roc curve

# %% [markdown]
# ![roc.png](data:image/png;base64,...)

# %%
# Validation data Confusion Matrix

# %% [markdown]
# ![ValConfusion.png](data:image/png;base64,...)

# %%
# Validation roc Curve

# %% [markdown]
# ![valRoc.png](data:image/png;base64,...)

# %%
'''
As per the analysis NavieBaye's provides good results both on test and validation score.
Also as roc_suc score is 0.80, the model is able to distinguish between 1 and 0
'''
